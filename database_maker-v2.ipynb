# %%
# %matplotlib inline
import sqlite3
import pandas as pd
import os
import numpy as np
import datetime as dt
# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, text, inspect, func
from flask import jsonify

# %%
# !pip install sqlalchemy
# !pip install flask

# %%
# List of folders containing the CSV files
folders = ['./Resources/arefin_data', './Resources/ellis_data', './Resources/rita_data', './Resources/uwagboe_data']

# Connect to SQLite database (this will create the file if it doesn't exist)
conn = sqlite3.connect('stockdata.sqlite')

for folder in folders:
    for file in os.listdir(folder):
        if file.endswith('.csv'):
            # Read CSV file into DataFrame
            df = pd.read_csv(os.path.join(folder, file))
            
            # Check if 'id' column exists, if not create it
            if 'id' not in df.columns:
                df.insert(0, 'id', range(1, 1 + len(df)))
            
            # Use the filename (without .csv) as the table name
            table_name = os.path.splitext(file)[0]
            
            # Convert DataFrame to SQL table in SQLite database
            df.to_sql(table_name, conn, if_exists='replace', index=False)

# Close the connection
conn.close()

# %%
# Now we retrieve the data from the database
# engine = create_engine("sqlite:///stockdata.sqlite")

# %%
# # reflect an existing database into a new model
# Base = automap_base() # Declare a Base using `automap_base()`
# # reflect the tables
# Base.prepare(engine, reflect=True) # Use the Base class to reflect the database tables

# %%
# # View all of the classes that automap found
# print(Base.classes.keys()) # Print all of the classes mapped to the Base

# %%
from sqlalchemy import inspect

engine = create_engine("sqlite:///stockdata.sqlite")
# Use the inspector to get the table names
inspector = inspect(engine)
table_names = inspector.get_table_names()

print(table_names)

# conn = engine.connect()
# result = conn.execute("SELECT name FROM sqlite_master WHERE type='table';")
# tables = result.fetchall()
# print(tables)
# conn.close()
# Out:
# ['AAPL', 'AMZN', 'ANSS', 'DXC', 'FFIV', 'GE', 'GOOGL', 'HPE', 'JNPR', 'KEYS', 'META', 'MSFT', 'MTD', 'NDVA', 'QRVO', 'S&P500companies', 'S&P500companies_technology', 'SEDG', 'TSLA', 'ZBH']

# %%
# Query data into a DataFrame by starting with the main comprehensive list 'S&P500companies'
conn = sqlite3.connect("stockdata.sqlite")
df = pd.read_sql_query("SELECT * FROM [S&P500companies]", conn)
df.head()
# Out:
#    id Symbol     Security             GICS Sector  \
# 0   1    MMM           3M             Industrials
# 1   2    AOS  A. O. Smith             Industrials
# 2   3    ABT       Abbott             Health Care
# 3   4   ABBV       AbbVie             Health Care
# 4   5    ACN    Accenture  Information Technology
#
#                 GICS Sub-Industry    Headquarters Location  Date added  \
# 0        Industrial Conglomerates    Saint Paul, Minnesota  1957-03-04
# 1               Building Products     Milwaukee, Wisconsin  2017-07-26
# 2           Health Care Equipment  North Chicago, Illinois  1957-03-04
# 3                 Pharmaceuticals  North Chicago, Illinois  2012-12-31
# 4  IT Consulting & Other Services          Dublin, Ireland  2011-07-06
#
#        CIK      Founded      LogoPath
# 0    66740         1902  NotAvailable
# 1    91142         1916  NotAvailable
# 2     1800         1888  NotAvailable
# 3  1551152  2013 (1888)  NotAvailable
# 4  1467373         1989  NotAvailable

# %%
print(df.head())
# Out:
#    id Ticker      Company                      Sub_sector  \
# 0   1    MMM           3M        Industrial Conglomerates
# 1   2    AOS  A. O. Smith               Building Products
# 2   3    ABT       Abbott           Health Care Equipment
# 3   4   ABBV       AbbVie                 Pharmaceuticals
# 4   5    ACN    Accenture  IT Consulting & Other Services
#
#               Headquarters  Date added      Founded      LogoPath
# 0    Saint Paul, Minnesota  1957-03-04         1902  NotAvailable
# 1     Milwaukee, Wisconsin  2017-07-26         1916  NotAvailable
# 2  North Chicago, Illinois  1957-03-04         1888  NotAvailable
# 3  North Chicago, Illinois  2012-12-31  2013 (1888)  NotAvailable
# 4          Dublin, Ireland  2011-07-06         1989  NotAvailable

# %%
# Rename some columns
df = df.rename(columns={'Symbol':'Ticker','Security':'Company','GICS Sub-Industry': 'Sub_sector', 'Headquarters Location': 'Headquarters'})
df.head()
# Out:
#    id Ticker      Company             GICS Sector  \
# 0   1    MMM           3M             Industrials
# 1   2    AOS  A. O. Smith             Industrials
# 2   3    ABT       Abbott             Health Care
# 3   4   ABBV       AbbVie             Health Care
# 4   5    ACN    Accenture  Information Technology
#
#                        Sub_sector             Headquarters  Date added  \
# 0        Industrial Conglomerates    Saint Paul, Minnesota  1957-03-04
# 1               Building Products     Milwaukee, Wisconsin  2017-07-26
# 2           Health Care Equipment  North Chicago, Illinois  1957-03-04
# 3                 Pharmaceuticals  North Chicago, Illinois  2012-12-31
# 4  IT Consulting & Other Services          Dublin, Ireland  2011-07-06
#
#        CIK      Founded      LogoPath
# 0    66740         1902  NotAvailable
# 1    91142         1916  NotAvailable
# 2     1800         1888  NotAvailable
# 3  1551152  2013 (1888)  NotAvailable
# 4  1467373         1989  NotAvailable

# %%
# Delete some columns 
df = df.drop(columns=['GICS Sector', 'CIK'])
# Show what's the current state of the df
df.head()
# Out:
#    id Ticker      Company                      Sub_sector  \
# 0   1    MMM           3M        Industrial Conglomerates
# 1   2    AOS  A. O. Smith               Building Products
# 2   3    ABT       Abbott           Health Care Equipment
# 3   4   ABBV       AbbVie                 Pharmaceuticals
# 4   5    ACN    Accenture  IT Consulting & Other Services
#
#               Headquarters  Date added      Founded      LogoPath
# 0    Saint Paul, Minnesota  1957-03-04         1902  NotAvailable
# 1     Milwaukee, Wisconsin  2017-07-26         1916  NotAvailable
# 2  North Chicago, Illinois  1957-03-04         1888  NotAvailable
# 3  North Chicago, Illinois  2012-12-31  2013 (1888)  NotAvailable
# 4          Dublin, Ireland  2011-07-06         1989  NotAvailable

# %%
# Construct the dictionaries
metadata = df.to_dict(orient='records')
# Print the resulting dictionary to verify
# print(data_dict)
metadata
# Out:
# [{'id': 1,
#   'Ticker': 'MMM',
#   'Company': '3M',
#   'Sub_sector': 'Industrial Conglomerates',
#   'Headquarters': 'Saint Paul, Minnesota',
#   'Date added': '1957-03-04',
#   'Founded': '1902',
#   'LogoPath': 'NotAvailable'},
#  {'id': 2,
#   'Ticker': 'AOS',
#   'Company': 'A. O. Smith',
#   'Sub_sector': 'Building Products',
#   'Headquarters': 'Milwaukee, Wisconsin',
#   'Date added': '2017-07-26',
#   'Founded': '1916',
#   'LogoPath': 'NotAvailable'},
#  {'id': 3,
#   'Ticker': 'ABT',
#   'Company': 'Abbott',
#   'Sub_sector': 'Health Care Equipment',
#   'Headquarters': 'North Chicago, Illinois',
#   'Date added': '1957-03-04',
#   'Founded': '1888',
#   'LogoPath': 'NotAvailable'},
#  {'id': 4,
#   'Ticker': 'ABBV',
#   'Company': 'AbbVie',
#   'Sub_sector': 'Pharmaceuticals',
#   'Headquarters': 'North Chicago, Illinois',
#   'Date added': '2012-12-31',
#   'Founded': '2013 (1888)',
#   'LogoPath': 'NotAvailable'},
#  {'id': 5,
#   'Ticker': 'ACN',
#   'Company': 'Accenture',
#   'Sub_sector': 'IT Consulting & Other Services',
#   'Headquarters': 'Dublin, Ireland',
#   'Date added': '2011-07-06',
#   'Founded': '1989',
#   'LogoPath': 'NotAvailable'},
#  {'id': 6,
#   'Ticker': 'ATVI',
#   'Company': 'Activision Blizzard',
#   'Sub_sector': 'Interactive Home Entertainment',
#   'Headquarters': 'Santa Monica, California',
#   'Date added': '2015-08-31',
#   'Founded': '2008',
#   'LogoPath': 'NotAvailable'},
#  {'id': 7,
#   'Ticker': 'ADM',
#   'Company': 'ADM',
#   'Sub_sector': 'Agricultural Products & Services',
#   'Headquarters': 'Chicago, Illinois',
#   'Date added': '1957-03-04',
#   'Founded': '1902',
#   'LogoPath': 'NotAvailable'},
#  {'id': 8,
#   'Ticker': 'ADBE',
#   'Company': 'Adobe Inc.',
#   'Sub_sector': 'Application Software',
#   'Headquarters': 'San Jose, California',
#   'Date added': '1997-05-05',
#   'Founded': '1982',
#   'LogoPath': 'NotAvailable'},
#  {'id': 9,
#   'Ticker': 'ADP',
#   'Company': 'ADP',
#   'Sub_sector': 'Human Resource & Employment Services',
#   'Headquarters': 'Roseland, New Jersey',
#   'Date added': '1981-03-31',
#   'Founded': '1949',
#   'LogoPath': 'NotAvailable'},
#  {'id': 10,
#   'Ticker': 'AAP',
#   'Company': 'Advance Auto Parts',
#   'Sub_sector': 'Automotive Retail',
#   'Headquarters': 'Raleigh, North Carolina',
#   'Date added': '2015-07-09',
#   'Founded': '1932',
#   'LogoPath': 'NotAvailable'},
#  {'id': 11,
#   'Ticker': 'AES',
#   'Company': 'AES Corporation',
#   'Sub_sector': 'Independent Power Producers & Energy Traders',
#   'Headquarters': 'Arlington, Virginia',
#   'Date added': '1998-10-02',
#   'Founded': '1981',
#   'LogoPath': 'NotAvailable'},
#  {'id': 12,
#   'Ticker': 'AFL',
#   'Company': 'Aflac',
#   'Sub_sector': 'Life & Health Insurance',
#   'Headquarters': 'Columbus, Georgia',
#   'Date added': '1999-05-28',
#   'Founded': '1955',
#   'LogoPath': 'NotAvailable'},
#  {'id': 13,
#   'Ticker': 'A',
#   'Company': 'Agilent Technologies',
#   'Sub_sector': 'Health Care Equipment',
#   'Headquarters': 'Santa Clara, California',
#   'Date added': '2000-06-05',
#   'Founded': '1999',
#   'LogoPath': 'NotAvailable'},
#  {'id': 14,
#   'Ticker': 'APD',
#   'Company': 'Air Products and Chemicals',
#   'Sub_sector': 'Industrial Gases',
#   'Headquarters': 'Allentown, Pennsylvania',
#   'Date added': '1985-04-30',
#   'Founded': '1940',
#   'LogoPath': 'NotAvailable'},
#  {'id': 15,
#   'Ticker': 'AKAM',
#   'Company': 'Akamai',
#   'Sub_sector': 'Internet Services & Infrastructure',
#   'Headquarters': 'Cambridge, Massachusetts',
#   'Date added': '2007-07-12',
#   'Founded': '1998',
#   'LogoPath': 'NotAvailable'},
#  {'id': 16,
#   'Ticker': 'ALK',
#   'Company': 'Alaska Air Group',
#   'Sub_sector': 'Passenger Airlines',
#   'Headquarters': 'SeaTac, Washington',
#   'Date added': '2016-05-13',
#   'Founded': '1985',
#   'LogoPath': 'NotAvailable'},
#  {'id': 17,
#   'Ticker': 'ALB',
#   'Company': 'Albemarle Corporation',
#   'Sub_sector': 'Specialty Chemicals',
#   'Headquarters': 'Charlotte, North Carolina',
#   'Date added': '2016-07-01',
#   'Founded': '1994',
#   'LogoPath': 'NotAvailable'},
#  {'id': 18,
#   'Ticker': 'ARE',
#   'Company': 'Alexandria Real Estate Equities',
#   'Sub_sector': 'Office REITs',
#   'Headquarters': 'Pasadena, California',
#   'Date added': '2017-03-20',
#   'Founded': '1994',
#   'LogoPath': 'NotAvailable'},
#  {'id': 19,
#   'Ticker': 'ALGN',
#   'Company': 'Align Technology',
#   'Sub_sector': 'Health Care Supplies',
#   'Headquarters': 'Tempe, Arizona',
#   'Date added': '2017-06-19',
#   'Founded': '1997',
#   'LogoPath': 'NotAvailable'},
#  {'id': 20,
#   'Ticker': 'ALLE',
#   'Company': 'Allegion',
#   'Sub_sector': 'Building Products',
#   'Headquarters': 'New York City, New York',
#   'Date added': '2013-12-02',
#   'Founded': '1908',
#   'LogoPath': 'NotAvailable'},
#  {'id': 21,
#   'Ticker': 'LNT',
#   'Company': 'Alliant Energy',
#   'Sub_sector': 'Electric Utilities',
#   'Headquarters': 'Madison, Wisconsin',
#   'Date added': '2016-07-01',
#   'Founded': '1917',
#   'LogoPath': 'NotAvailable'},
#  {'id': 22,
#   'Ticker': 'ALL',
#   'Company': 'Allstate',
#   'Sub_sector': 'Property & Casualty Insurance',
#   'Headquarters': 'Glenview, Illinois',
#   'Date added': '1995-07-13',
#   'Founded': '1931',
#   'LogoPath': 'NotAvailable'},
#  {'id': 23,
#   'Ticker': 'GOOGL',
#   'Company': 'Alphabet Inc. (Class A)',
#   'Sub_sector': 'Interactive Media & Services',
#   'Headquarters': 'Mountain View, California',
#   'Date added': '2014-04-03',
#   'Founded': '1998',
#   'LogoPath': './Resources/GOOGL.png'},
#  {'id': 24,
#   'Ticker': 'GOOG',
#   'Company': 'Alphabet Inc. (Class C)',
#   'Sub_sector': 'Interactive Media & Services',
#   'Headquarters': 'Mountain View, California',
#   'Date added': '2006-04-03',
#   'Founded': '1998',
#   'LogoPath': 'NotAvailable'},
#  {'id': 25,
#   'Ticker': 'MO',
#   'Company': 'Altria',
#   'Sub_sector': 'Tobacco',
#   'Headquarters': 'Richmond, Virginia',
#   'Date added': '1957-03-04',
#   'Founded': '1985',
#   'LogoPath': 'NotAvailable'},
#  {'id': 26,
#   'Ticker': 'AMZN',
#   'Company': 'Amazon',
#   'Sub_sector': 'Broadline Retail',
#   'Headquarters': 'Seattle, Washington',
#   'Date added': '2005-11-18',
#   'Founded': '1994',
#   'LogoPath': './Resources/AMZN.png'},
#  {'id': 27,
#   'Ticker': 'AMCR',
#   'Company': 'Amcor',
#   'Sub_sector': 'Paper & Plastic Packaging Products & Materials',
#   'Headquarters': 'Warmley, Bristol, United Kingdom',
#   'Date added': '2019-06-07',
#   'Founded': '2019 (1860)',
#   'LogoPath': 'NotAvailable'},
#  {'id': 28,
#   'Ticker': 'AMD',
#   'Company': 'AMD',
#   'Sub_sector': 'Semiconductors',
#   'Headquarters': 'Santa Clara, California',
#   'Date added': '2017-03-20',
#   'Founded': '1969',
#   'LogoPath': 'NotAvailable'},
#  {'id': 29,
#   'Ticker': 'AEE',
#   'Company': 'Ameren',
#   'Sub_sector': 'Multi-Utilities',
#   'Headquarters': 'St. Louis, Missouri',
#   'Date added': '1991-09-19',
#   'Founded': '1902',
#   'LogoPath': 'NotAvailable'},
#  {'id': 30,
#   'Ticker': 'AAL',
#   'Company': 'American Airlines Group',
#   'Sub_sector': 'Passenger Airlines',
#   'Headquarters': 'Fort Worth, Texas',
#   'Date added': '2015-03-23',
#   'Founded': '1934',
#   'LogoPath': 'NotAvailable'},
#  {'id': 31,
#   'Ticker': 'AEP',
#   'Company': 'American Electric Power',
#   'Sub_sector': 'Electric Utilities',
#   'Headquarters': 'Columbus, Ohio',
#   'Date added': '1957-03-04',
#   'Founded': '1906',
#   'LogoPath': 'NotAvailable'},
#  {'id': 32,
#   'Ticker': 'AXP',
#   'Company': 'American Express',
#   'Sub_sector': 'Consumer Finance',
#   'Headquarters': 'New York City, New York',
#   'Date added': '1976-06-30',
#   'Founded': '1850',
#   'LogoPath': 'NotAvailable'},
#  {'id': 33,
#   'Ticker': 'AIG',
#   'Company': 'American International Group',
#   'Sub_sector': 'Property & Casualty Insurance',
#   'Headquarters': 'New York City, New York',
#   'Date added': '1980-03-31',
#   'Founded': '1919',
#   'LogoPath': 'NotAvailable'},
#  {'id': 34,
#   'Ticker': 'AMT',
#   'Company': 'American Tower',
#   'Sub_sector': 'Telecom Tower REITs',
#   'Headquarters': 'Boston, Massachusetts',
#   'Date added': '2007-11-19',
#   'Founded': '1995',
#   'LogoPath': 'NotAvailable'},
#  {'id': 35,
#   'Ticker': 'AWK',
#   'Company': 'American Water Works',
#   'Sub_sector': 'Water Utilities',
#   'Headquarters': 'Camden, New Jersey',
#   'Date added': '2016-03-04',
#   'Founded': '1886',
#   'LogoPath': 'NotAvailable'},
#  {'id': 36,
#   'Ticker': 'AMP',
#   'Company': 'Ameriprise Financial',
#   'Sub_sector': 'Asset Management & Custody Banks',
#   'Headquarters': 'Minneapolis, Minnesota',
#   'Date added': '2005-10-03',
#   'Founded': '1894',
#   'LogoPath': 'NotAvailable'},
#  {'id': 37,
#   'Ticker': 'ABC',
#   'Company': 'AmerisourceBergen',
#   'Sub_sector': 'Health Care Distributors',
#   'Headquarters': 'Conshohocken, Pennsylvania',
#   'Date added': '2001-08-30',
#   'Founded': '1985',
#   'LogoPath': 'NotAvailable'},
#  {'id': 38,
#   'Ticker': 'AME',
#   'Company': 'Ametek',
#   'Sub_sector': 'Electrical Components & Equipment',
#   'Headquarters': 'Berwyn, Pennsylvania',
#   'Date added': '2013-09-23',
#   'Founded': '1930',
#   'LogoPath': 'NotAvailable'},
#  {'id': 39,
#   'Ticker': 'AMGN',
#   'Company': 'Amgen',
#   'Sub_sector': 'Biotechnology',
#   'Headquarters': 'Thousand Oaks, California',
#   'Date added': '1992-01-02',
#   'Founded': '1980',
#   'LogoPath': 'NotAvailable'},
#  {'id': 40,
#   'Ticker': 'APH',
#   'Company': 'Amphenol',
#   'Sub_sector': 'Electronic Components',
#   'Headquarters': 'Wallingford, Connecticut',
#   'Date added': '2008-09-30',
#   'Founded': '1932',
#   'LogoPath': 'NotAvailable'},
#  {'id': 41,
#   'Ticker': 'ADI',
#   'Company': 'Analog Devices',
#   'Sub_sector': 'Semiconductors',
#   'Headquarters': 'Wilmington, Massachusetts',
#   'Date added': '1999-10-12',
#   'Founded': '1965',
#   'LogoPath': 'NotAvailable'},
#  {'id': 42,
#   'Ticker': 'ANSS',
#   'Company': 'Ansys',
#   'Sub_sector': 'Application Software',
#   'Headquarters': 'Canonsburg, Pennsylvania',
#   'Date added': '2017-06-19',
#   'Founded': '1969',
#   'LogoPath': './Resources/ANSS.png'},
#  {'id': 43,
#   'Ticker': 'AON',
#   'Company': 'Aon',
#   'Sub_sector': 'Insurance Brokers',
#   'Headquarters': 'London, UK',
#   'Date added': '1996-04-23',
#   'Founded': '1982 (1919)',
#   'LogoPath': 'NotAvailable'},
#  {'id': 44,
#   'Ticker': 'APA',
#   'Company': 'APA Corporation',
#   'Sub_sector': 'Oil & Gas Exploration & Production',
#   'Headquarters': 'Houston, Texas',
#   'Date added': '1997-07-28',
#   'Founded': '1954',
#   'LogoPath': 'NotAvailable'},
#  {'id': 45,
#   'Ticker': 'AAPL',
#   'Company': 'Apple Inc.',
#   'Sub_sector': 'Technology Hardware, Storage & Peripherals',
#   'Headquarters': 'Cupertino, California',
#   'Date added': '1982-11-30',
#   'Founded': '1977',
#   'LogoPath': './Resources/AAPL.png'},
#  {'id': 46,
#   'Ticker': 'AMAT',
#   'Company': 'Applied Materials',
#   'Sub_sector': 'Semiconductor Materials & Equipment',
#   'Headquarters': 'Santa Clara, California',
#   'Date added': '1995-03-16',
#   'Founded': '1967',
#   'LogoPath': 'NotAvailable'},
#  {'id': 47,
#   'Ticker': 'APTV',
#   'Company': 'Aptiv',
#   'Sub_sector': 'Automotive Parts & Equipment',
#   'Headquarters': 'Dublin, Ireland',
#   'Date added': '2012-12-24',
#   'Founded': '1994',
#   'LogoPath': 'NotAvailable'},
#  {'id': 48,
#   'Ticker': 'ACGL',
#   'Company': 'Arch Capital Group',
#   'Sub_sector': 'Reinsurance',
#   'Headquarters': 'Hamilton, Bermuda',
#   'Date added': '2022-11-01',
#   'Founded': '1995',
#   'LogoPath': 'NotAvailable'},
#  {'id': 49,
#   'Ticker': 'ANET',
#   'Company': 'Arista Networks',
#   'Sub_sector': 'Communications Equipment',
#   'Headquarters': 'Santa Clara, California',
#   'Date added': '2018-08-28',
#   'Founded': '2004',
#   'LogoPath': 'NotAvailable'},
#  {'id': 50,
#   'Ticker': 'AJG',
#   'Company': 'Arthur J. Gallagher & Co.',
#   'Sub_sector': 'Insurance Brokers',
#   'Headquarters': 'Rolling Meadows, Illinois',
#   'Date added': '2016-05-31',
#   'Founded': '1927',
#   'LogoPath': 'NotAvailable'},
#  {'id': 51,
#   'Ticker': 'AIZ',
#   'Company': 'Assurant',
#   'Sub_sector': 'Multi-line Insurance',
#   'Headquarters': 'New York City, New York',
#   'Date added': '2007-04-10',
#   'Founded': '1892',
#   'LogoPath': 'NotAvailable'},
#  {'id': 52,
#   'Ticker': 'T',
#   'Company': 'AT&T',
#   'Sub_sector': 'Integrated Telecommunication Services',
#   'Headquarters': 'Dallas, Texas',
#   'Date added': '1983-11-30',
#   'Founded': '1983 (1885)',
#   'LogoPath': 'NotAvailable'},
#  {'id': 53,
#   'Ticker': 'ATO',
#   'Company': 'Atmos Energy',
#   'Sub_sector': 'Gas Utilities',
#   'Headquarters': 'Dallas, Texas',
#   'Date added': '2019-02-15',
#   'Founded': '1906',
#   'LogoPath': 'NotAvailable'},
#  {'id': 54,
#   'Ticker': 'ADSK',
#   'Company': 'Autodesk',
#   'Sub_sector': 'Application Software',
#   'Headquarters': 'San Francisco, California',
#   'Date added': '1989-12-01',
#   'Founded': '1982',
#   'LogoPath': 'NotAvailable'},
#  {'id': 55,
#   'Ticker': 'AZO',
#   'Company': 'AutoZone',
#   'Sub_sector': 'Specialty Stores',
#   'Headquarters': 'Memphis, Tennessee',
#   'Date added': '1997-01-02',
#   'Founded': '1979',
#   'LogoPath': 'NotAvailable'},
#  {'id': 56,
#   'Ticker': 'AVB',
#   'Company': 'AvalonBay Communities',
#   'Sub_sector': 'Residential REITs',
#   'Headquarters': 'Arlington, Virginia',
#   'Date added': '2007-01-10',
#   'Founded': '1978',
#   'LogoPath': 'NotAvailable'},
#  {'id': 57,
#   'Ticker': 'AVY',
#   'Company': 'Avery Dennison',
#   'Sub_sector': 'Paper & Plastic Packaging Products & Materials',
#   'Headquarters': 'Glendale, California',
#   'Date added': '1987-12-31',
#   'Founded': '1990',
#   'LogoPath': 'NotAvailable'},
#  {'id': 58,
#   'Ticker': 'AXON',
#   'Company': 'Axon Enterprise',
#   'Sub_sector': 'Aerospace & Defense',
#   'Headquarters': 'Scottsdale, Arizona',
#   'Date added': '2023-05-04',
#   'Founded': '1993',
#   'LogoPath': 'NotAvailable'},
#  {'id': 59,
#   'Ticker': 'BKR',
#   'Company': 'Baker Hughes',
#   'Sub_sector': 'Oil & Gas Equipment & Services',
#   'Headquarters': 'Houston, Texas',
#   'Date added': '2017-07-07',
#   'Founded': '2017',
#   'LogoPath': 'NotAvailable'},
#  {'id': 60,
#   'Ticker': 'BALL',
#   'Company': 'Ball Corporation',
#   'Sub_sector': 'Metal, Glass & Plastic Containers',
#   'Headquarters': 'Broomfield, Colorado',
#   'Date added': '1984-10-31',
#   'Founded': '1880',
#   'LogoPath': 'NotAvailable'},
#  {'id': 61,
#   'Ticker': 'BAC',
#   'Company': 'Bank of America',
#   'Sub_sector': 'Diversified Banks',
#   'Headquarters': 'Charlotte, North Carolina',
#   'Date added': '1976-06-30',
#   'Founded': '1998 (1923 / 1874)',
#   'LogoPath': 'NotAvailable'},
#  {'id': 62,
#   'Ticker': 'BBWI',
#   'Company': 'Bath & Body Works, Inc.',
#   'Sub_sector': 'Specialty Stores',
#   'Headquarters': 'Columbus, Ohio',
#   'Date added': '1983-09-30',
#   'Founded': '1963',
#   'LogoPath': 'NotAvailable'},
#  {'id': 63,
#   'Ticker': 'BAX',
#   'Company': 'Baxter International',
#   'Sub_sector': 'Health Care Equipment',
#   'Headquarters': 'Deerfield, Illinois',
#   'Date added': '1972-09-30',
#   'Founded': '1931',
#   'LogoPath': 'NotAvailable'},
#  {'id': 64,
#   'Ticker': 'BDX',
#   'Company': 'Becton Dickinson',
#   'Sub_sector': 'Health Care Equipment',
#   'Headquarters': 'Franklin Lakes, New Jersey',
#   'Date added': '1972-09-30',
#   'Founded': '1897',
#   'LogoPath': 'NotAvailable'},
#  {'id': 65,
#   'Ticker': 'WRB',
#   'Company': 'Berkley',
#   'Sub_sector': 'Property & Casualty Insurance',
#   'Headquarters': 'Greenwich, Connecticut',
#   'Date added': '2019-12-05',
#   'Founded': '1967',
#   'LogoPath': 'NotAvailable'},
#  {'id': 66,
#   'Ticker': 'BRK.B',
#   'Company': 'Berkshire Hathaway',
#   'Sub_sector': 'Multi-Sector Holdings',
#   'Headquarters': 'Omaha, Nebraska',
#   'Date added': '2010-02-16',
#   'Founded': '1839',
#   'LogoPath': 'NotAvailable'},
#  {'id': 67,
#   'Ticker': 'BBY',
#   'Company': 'Best Buy',
#   'Sub_sector': 'Computer & Electronics Retail',
#   'Headquarters': 'Richfield, Minnesota',
#   'Date added': '1999-06-29',
#   'Founded': '1966',
#   'LogoPath': 'NotAvailable'},
#  {'id': 68,
#   'Ticker': 'BIO',
#   'Company': 'Bio-Rad',
#   'Sub_sector': 'Life Sciences Tools & Services',
#   'Headquarters': 'Hercules, California',
#   'Date added': '2020-06-22',
#   'Founded': '1952',
#   'LogoPath': 'NotAvailable'},
#  {'id': 69,
#   'Ticker': 'TECH',
#   'Company': 'Bio-Techne',
#   'Sub_sector': 'Life Sciences Tools & Services',
#   'Headquarters': 'Minneapolis, Minnesota',
#   'Date added': '2021-08-30',
#   'Founded': '1976',
#   'LogoPath': 'NotAvailable'},
#  {'id': 70,
#   'Ticker': 'BIIB',
#   'Company': 'Biogen',
#   'Sub_sector': 'Biotechnology',
#   'Headquarters': 'Cambridge, Massachusetts',
#   'Date added': '2003-11-13',
#   'Founded': '1978',
#   'LogoPath': 'NotAvailable'},
#  {'id': 71,
#   'Ticker': 'BLK',
#   'Company': 'BlackRock',
#   'Sub_sector': 'Asset Management & Custody Banks',
#   'Headquarters': 'New York City, New York',
#   'Date added': '2011-04-04',
#   'Founded': '1988',
#   'LogoPath': 'NotAvailable'},
#  {'id': 72,
#   'Ticker': 'BK',
#   'Company': 'BNY Mellon',
#   'Sub_sector': 'Asset Management & Custody Banks',
#   'Headquarters': 'New York City, New York',
#   'Date added': '1995-03-31',
#   'Founded': '1784',
#   'LogoPath': 'NotAvailable'},
#  {'id': 73,
#   'Ticker': 'BA',
#   'Company': 'Boeing',
#   'Sub_sector': 'Aerospace & Defense',
#   'Headquarters': 'Chicago, Illinois',
#   'Date added': '1957-03-04',
#   'Founded': '1916',
#   'LogoPath': 'NotAvailable'},
#  {'id': 74,
#   'Ticker': 'BKNG',
#   'Company': 'Booking Holdings',
#   'Sub_sector': 'Hotels, Restaurants & Leisure',
#   'Headquarters': 'Norwalk, Connecticut',
#   'Date added': '2009-11-06',
#   'Founded': '1996',
#   'LogoPath': 'NotAvailable'},
#  {'id': 75,
#   'Ticker': 'BWA',
#   'Company': 'BorgWarner',
#   'Sub_sector': 'Automotive Parts & Equipment',
#   'Headquarters': 'Auburn Hills, Michigan',
#   'Date added': '2011-12-19',
#   'Founded': '1880',
#   'LogoPath': 'NotAvailable'},
#  {'id': 76,
#   'Ticker': 'BXP',
#   'Company': 'Boston Properties',
#   'Sub_sector': 'Office REITs',
#   'Headquarters': 'Boston, Massachusetts',
#   'Date added': '2006-04-03',
#   'Founded': '1970',
#   'LogoPath': 'NotAvailable'},
#  {'id': 77,
#   'Ticker': 'BSX',
#   'Company': 'Boston Scientific',
#   'Sub_sector': 'Health Care Equipment',
#   'Headquarters': 'Marlborough, Massachusetts',
#   'Date added': '1995-02-24',
#   'Founded': '1979',
#   'LogoPath': 'NotAvailable'},
#  {'id': 78,
#   'Ticker': 'BMY',
#   'Company': 'Bristol Myers Squibb',
#   'Sub_sector': 'Pharmaceuticals',
#   'Headquarters': 'New York City, New York',
#   'Date added': '1957-03-04',
#   'Founded': '1989 (1887)',
#   'LogoPath': 'NotAvailable'},
#  {'id': 79,
#   'Ticker': 'AVGO',
#   'Company': 'Broadcom Inc.',
#   'Sub_sector': 'Semiconductors',
#   'Headquarters': 'San Jose, California',
#   'Date added': '2014-05-08',
#   'Founded': '1961',
#   'LogoPath': 'NotAvailable'},
#  {'id': 80,
#   'Ticker': 'BR',
#   'Company': 'Broadridge Financial Solutions',
#   'Sub_sector': 'Data Processing & Outsourced Services',
#   'Headquarters': 'Lake Success, New York',
#   'Date added': '2018-06-18',
#   'Founded': '1962',
#   'LogoPath': 'NotAvailable'},
#  {'id': 81,
#   'Ticker': 'BRO',
#   'Company': 'Brown & Brown',
#   'Sub_sector': 'Insurance Brokers',
#   'Headquarters': 'Daytona Beach, Florida',
#   'Date added': '2021-09-20',
#   'Founded': '1939',
#   'LogoPath': 'NotAvailable'},
#  {'id': 82,
#   'Ticker': 'BF.B',
#   'Company': 'Brown–Forman',
#   'Sub_sector': 'Distillers & Vintners',
#   'Headquarters': 'Louisville, Kentucky',
#   'Date added': '1982-10-31',
#   'Founded': '1870',
#   'LogoPath': 'NotAvailable'},
#  {'id': 83,
#   'Ticker': 'BG',
#   'Company': 'Bunge Limited',
#   'Sub_sector': 'Agricultural Products & Services',
#   'Headquarters': 'Chesterfield, Missouri',
#   'Date added': '2023-03-15',
#   'Founded': '1818',
#   'LogoPath': 'NotAvailable'},
#  {'id': 84,
#   'Ticker': 'CHRW',
#   'Company': 'C.H. Robinson',
#   'Sub_sector': 'Air Freight & Logistics',
#   'Headquarters': 'Eden Prairie, Minnesota',
#   'Date added': '2007-03-02',
#   'Founded': '1905',
#   'LogoPath': 'NotAvailable'},
#  {'id': 85,
#   'Ticker': 'CDNS',
#   'Company': 'Cadence Design Systems',
#   'Sub_sector': 'Application Software',
#   'Headquarters': 'San Jose, California',
#   'Date added': '2017-09-18',
#   'Founded': '1988',
#   'LogoPath': 'NotAvailable'},
#  {'id': 86,
#   'Ticker': 'CZR',
#   'Company': 'Caesars Entertainment',
#   'Sub_sector': 'Casinos & Gaming',
#   'Headquarters': 'Reno, Nevada',
#   'Date added': '2021-03-22',
#   'Founded': '1973',
#   'LogoPath': 'NotAvailable'},
#  {'id': 87,
#   'Ticker': 'CPT',
#   'Company': 'Camden Property Trust',
#   'Sub_sector': 'Residential REITs',
#   'Headquarters': 'Houston, Texas',
#   'Date added': '2022-04-04',
#   'Founded': '1981',
#   'LogoPath': 'NotAvailable'},
#  {'id': 88,
#   'Ticker': 'CPB',
#   'Company': 'Campbell Soup Company',
#   'Sub_sector': 'Packaged Foods & Meats',
#   'Headquarters': 'Camden, New Jersey',
#   'Date added': '1957-03-04',
#   'Founded': '1869',
#   'LogoPath': 'NotAvailable'},
#  {'id': 89,
#   'Ticker': 'COF',
#   'Company': 'Capital One',
#   'Sub_sector': 'Consumer Finance',
#   'Headquarters': 'Tysons Corner, Virginia',
#   'Date added': '1998-07-01',
#   'Founded': '1994',
#   'LogoPath': 'NotAvailable'},
#  {'id': 90,
#   'Ticker': 'CAH',
#   'Company': 'Cardinal Health',
#   'Sub_sector': 'Health Care Distributors',
#   'Headquarters': 'Dublin, Ohio',
#   'Date added': '1997-05-27',
#   'Founded': '1971',
#   'LogoPath': 'NotAvailable'},
#  {'id': 91,
#   'Ticker': 'KMX',
#   'Company': 'CarMax',
#   'Sub_sector': 'Automotive Retail',
#   'Headquarters': 'Richmond, Virginia',
#   'Date added': '2010-06-28',
#   'Founded': '1993',
#   'LogoPath': 'NotAvailable'},
#  {'id': 92,
#   'Ticker': 'CCL',
#   'Company': 'Carnival',
#   'Sub_sector': 'Hotels, Resorts & Cruise Lines',
#   'Headquarters': 'Miami, Florida',
#   'Date added': '1998-12-22',
#   'Founded': '1972',
#   'LogoPath': 'NotAvailable'},
#  {'id': 93,
#   'Ticker': 'CARR',
#   'Company': 'Carrier Global',
#   'Sub_sector': 'Building Products',
#   'Headquarters': 'Palm Beach Gardens, Florida',
#   'Date added': '2020-04-03',
#   'Founded': '2020 (1915)',
#   'LogoPath': 'NotAvailable'},
#  {'id': 94,
#   'Ticker': 'CTLT',
#   'Company': 'Catalent',
#   'Sub_sector': 'Pharmaceuticals',
#   'Headquarters': 'Somerset, New Jersey',
#   'Date added': '2020-09-21',
#   'Founded': '2007',
#   'LogoPath': 'NotAvailable'},
#  {'id': 95,
#   'Ticker': 'CAT',
#   'Company': 'Caterpillar Inc.',
#   'Sub_sector': 'Construction Machinery & Heavy Transportation Equipment',
#   'Headquarters': 'Irving, Texas',
#   'Date added': '1957-03-04',
#   'Founded': '1925',
#   'LogoPath': 'NotAvailable'},
#  {'id': 96,
#   'Ticker': 'CBOE',
#   'Company': 'Cboe Global Markets',
#   'Sub_sector': 'Financial Exchanges & Data',
#   'Headquarters': 'Chicago, Illinois',
#   'Date added': '2017-03-01',
#   'Founded': '1973',
#   'LogoPath': 'NotAvailable'},
#  {'id': 97,
#   'Ticker': 'CBRE',
#   'Company': 'CBRE Group',
#   'Sub_sector': 'Real Estate Services',
#   'Headquarters': 'Dallas, Texas',
#   'Date added': '2006-11-10',
#   'Founded': '1906',
#   'LogoPath': 'NotAvailable'},
#  {'id': 98,
#   'Ticker': 'CDW',
#   'Company': 'CDW',
#   'Sub_sector': 'Technology Distributors',
#   'Headquarters': 'Lincolnshire, Illinois',
#   'Date added': '2019-09-23',
#   'Founded': '1984',
#   'LogoPath': 'NotAvailable'},
#  {'id': 99,
#   'Ticker': 'CE',
#   'Company': 'Celanese',
#   'Sub_sector': 'Specialty Chemicals',
#   'Headquarters': 'Irving, Texas',
#   'Date added': '2018-12-24',
#   'Founded': '1918',
#   'LogoPath': 'NotAvailable'},
#  {'id': 100,
#   'Ticker': 'CNC',
#   'Company': 'Centene Corporation',
#   'Sub_sector': 'Managed Health Care',
#   'Headquarters': 'St. Louis, Missouri',
#   'Date added': '2016-03-30',
#   'Founded': '1984',
#   'LogoPath': 'NotAvailable'},
#  {'id': 101,
#   'Ticker': 'CNP',
#   'Company': 'CenterPoint Energy',
#   'Sub_sector': 'Multi-Utilities',
#   'Headquarters': 'Houston, Texas',
#   'Date added': '1985-07-31',
#   'Founded': '1882',
#   'LogoPath': 'NotAvailable'},
#  {'id': 102,
#   'Ticker': 'CDAY',
#   'Company': 'Ceridian',
#   'Sub_sector': 'Application Software',
#   'Headquarters': 'Minneapolis, Minnesota',
#   'Date added': '2021-09-20',
#   'Founded': '1992',
#   'LogoPath': 'NotAvailable'},
#  {'id': 103,
#   'Ticker': 'CF',
#   'Company': 'CF Industries',
#   'Sub_sector': 'Fertilizers & Agricultural Chemicals',
#   'Headquarters': 'Deerfield, Illinois',
#   'Date added': '2008-08-27',
#   'Founded': '1946',
#   'LogoPath': 'NotAvailable'},
#  {'id': 104,
#   'Ticker': 'CRL',
#   'Company': 'Charles River Laboratories',
#   'Sub_sector': 'Life Sciences Tools & Services',
#   'Headquarters': 'Wilmington, Massachusetts',
#   'Date added': '2021-05-14',
#   'Founded': '1947',
#   'LogoPath': 'NotAvailable'},
#  {'id': 105,
#   'Ticker': 'SCHW',
#   'Company': 'Charles Schwab Corporation',
#   'Sub_sector': 'Investment Banking & Brokerage',
#   'Headquarters': 'Westlake, Texas',
#   'Date added': '1997-06-02',
#   'Founded': '1971',
#   'LogoPath': 'NotAvailable'},
#  {'id': 106,
#   'Ticker': 'CHTR',
#   'Company': 'Charter Communications',
#   'Sub_sector': 'Cable & Satellite',
#   'Headquarters': 'Stamford, Connecticut',
#   'Date added': '2016-09-08',
#   'Founded': '1993',
#   'LogoPath': 'NotAvailable'},
#  {'id': 107,
#   'Ticker': 'CVX',
#   'Company': 'Chevron Corporation',
#   'Sub_sector': 'Integrated Oil & Gas',
#   'Headquarters': 'San Ramon, California',
#   'Date added': '1957-03-04',
#   'Founded': '1879',
#   'LogoPath': 'NotAvailable'},
#  {'id': 108,
#   'Ticker': 'CMG',
#   'Company': 'Chipotle Mexican Grill',
#   'Sub_sector': 'Restaurants',
#   'Headquarters': 'Newport Beach, California',
#   'Date added': '2011-04-28',
#   'Founded': '1993',
#   'LogoPath': 'NotAvailable'},
#  {'id': 109,
#   'Ticker': 'CB',
#   'Company': 'Chubb Limited',
#   'Sub_sector': 'Property & Casualty Insurance',
#   'Headquarters': 'Zurich, Switzerland',
#   'Date added': '2010-07-15',
#   'Founded': '1985',
#   'LogoPath': 'NotAvailable'},
#  {'id': 110,
#   'Ticker': 'CHD',
#   'Company': 'Church & Dwight',
#   'Sub_sector': 'Household Products',
#   'Headquarters': 'Ewing, New Jersey',
#   'Date added': '2015-12-29',
#   'Founded': '1847',
#   'LogoPath': 'NotAvailable'},
#  {'id': 111,
#   'Ticker': 'CI',
#   'Company': 'Cigna',
#   'Sub_sector': 'Managed Health Care',
#   'Headquarters': 'Bloomfield, Connecticut',
#   'Date added': '1976-06-30',
#   'Founded': '1982',
#   'LogoPath': 'NotAvailable'},
#  {'id': 112,
#   'Ticker': 'CINF',
#   'Company': 'Cincinnati Financial',
#   'Sub_sector': 'Property & Casualty Insurance',
#   'Headquarters': 'Fairfield, Ohio',
#   'Date added': '1997-12-18',
#   'Founded': '1950',
#   'LogoPath': 'NotAvailable'},
#  {'id': 113,
#   'Ticker': 'CTAS',
#   'Company': 'Cintas',
#   'Sub_sector': 'Diversified Support Services',
#   'Headquarters': 'Mason, Ohio',
#   'Date added': '2001-03-01',
#   'Founded': '1929',
#   'LogoPath': 'NotAvailable'},
#  {'id': 114,
#   'Ticker': 'CSCO',
#   'Company': 'Cisco',
#   'Sub_sector': 'Communications Equipment',
#   'Headquarters': 'San Jose, California',
#   'Date added': '1993-12-01',
#   'Founded': '1984',
#   'LogoPath': 'NotAvailable'},
#  {'id': 115,
#   'Ticker': 'C',
#   'Company': 'Citigroup',
#   'Sub_sector': 'Diversified Banks',
#   'Headquarters': 'New York City, New York',
#   'Date added': '1988-05-31',
#   'Founded': '1998',
#   'LogoPath': 'NotAvailable'},
#  {'id': 116,
#   'Ticker': 'CFG',
#   'Company': 'Citizens Financial Group',
#   'Sub_sector': 'Regional Banks',
#   'Headquarters': 'Providence, Rhode Island',
#   'Date added': '2016-01-29',
#   'Founded': '1828',
#   'LogoPath': 'NotAvailable'},
#  {'id': 117,
#   'Ticker': 'CLX',
#   'Company': 'Clorox',
#   'Sub_sector': 'Household Products',
#   'Headquarters': 'Oakland, California',
#   'Date added': '1969-03-31',
#   'Founded': '1913',
#   'LogoPath': 'NotAvailable'},
#  {'id': 118,
#   'Ticker': 'CME',
#   'Company': 'CME Group',
#   'Sub_sector': 'Financial Exchanges & Data',
#   'Headquarters': 'Chicago, Illinois',
#   'Date added': '2006-08-11',
#   'Founded': '1848',
#   'LogoPath': 'NotAvailable'},
#  {'id': 119,
#   'Ticker': 'CMS',
#   'Company': 'CMS Energy',
#   'Sub_sector': 'Multi-Utilities',
#   'Headquarters': 'Jackson, Michigan',
#   'Date added': '1957-03-04',
#   'Founded': '1886',
#   'LogoPath': 'NotAvailable'},
#  {'id': 120,
#   'Ticker': 'KO',
#   'Company': 'Coca-Cola Company (The)',
#   'Sub_sector': 'Soft Drinks & Non-alcoholic Beverages',
#   'Headquarters': 'Atlanta, Georgia',
#   'Date added': '1957-03-04',
#   'Founded': '1886',
#   'LogoPath': 'NotAvailable'},
#  {'id': 121,
#   'Ticker': 'CTSH',
#   'Company': 'Cognizant',
#   'Sub_sector': 'IT Consulting & Other Services',
#   'Headquarters': 'Teaneck, New Jersey',
#   'Date added': '2006-11-17',
#   'Founded': '1994',
#   'LogoPath': 'NotAvailable'},
#  {'id': 122,
#   'Ticker': 'CL',
#   'Company': 'Colgate-Palmolive',
#   'Sub_sector': 'Household Products',
#   'Headquarters': 'New York City, New York',
#   'Date added': '1957-03-04',
#   'Founded': '1806',
#   'LogoPath': 'NotAvailable'},
#  {'id': 123,
#   'Ticker': 'CMCSA',
#   'Company': 'Comcast',
#   'Sub_sector': 'Cable & Satellite',
#   'Headquarters': 'Philadelphia, Pennsylvania',
#   'Date added': '2002-11-19',
#   'Founded': '1963',
#   'LogoPath': 'NotAvailable'},
#  {'id': 124,
#   'Ticker': 'CMA',
#   'Company': 'Comerica',
#   'Sub_sector': 'Diversified Banks',
#   'Headquarters': 'Dallas, Texas',
#   'Date added': '1995-12-01',
#   'Founded': '1849',
#   'LogoPath': 'NotAvailable'},
#  {'id': 125,
#   'Ticker': 'CAG',
#   'Company': 'Conagra Brands',
#   'Sub_sector': 'Packaged Foods & Meats',
#   'Headquarters': 'Chicago, Illinois',
#   'Date added': '1983-08-31',
#   'Founded': '1919',
#   'LogoPath': 'NotAvailable'},
#  {'id': 126,
#   'Ticker': 'COP',
#   'Company': 'ConocoPhillips',
#   'Sub_sector': 'Oil & Gas Exploration & Production',
#   'Headquarters': 'Houston, Texas',
#   'Date added': '1957-03-04',
#   'Founded': '2002',
#   'LogoPath': 'NotAvailable'},
#  {'id': 127,
#   'Ticker': 'ED',
#   'Company': 'Consolidated Edison',
#   'Sub_sector': 'Electric Utilities',
#   'Headquarters': 'New York City, New York',
#   'Date added': '1957-03-04',
#   'Founded': '1823',
#   'LogoPath': 'NotAvailable'},
#  {'id': 128,
#   'Ticker': 'STZ',
#   'Company': 'Constellation Brands',
#   'Sub_sector': 'Distillers & Vintners',
#   'Headquarters': 'Victor, New York',
#   'Date added': '2005-07-01',
#   'Founded': '1945',
#   'LogoPath': 'NotAvailable'},
#  {'id': 129,
#   'Ticker': 'CEG',
#   'Company': 'Constellation Energy',
#   'Sub_sector': 'Multi-Utilities',
#   'Headquarters': 'Baltimore, Maryland',
#   'Date added': '2022-02-02',
#   'Founded': '1999',
#   'LogoPath': 'NotAvailable'},
#  {'id': 130,
#   'Ticker': 'COO',
#   'Company': 'CooperCompanies',
#   'Sub_sector': 'Health Care Supplies',
#   'Headquarters': 'San Ramon, California',
#   'Date added': '2016-09-23',
#   'Founded': '1958',
#   'LogoPath': 'NotAvailable'},
#  {'id': 131,
#   'Ticker': 'CPRT',
#   'Company': 'Copart',
#   'Sub_sector': 'Diversified Support Services',
#   'Headquarters': 'Dallas, Texas',
#   'Date added': '2018-07-02',
#   'Founded': '1982',
#   'LogoPath': 'NotAvailable'},
#  {'id': 132,
#   'Ticker': 'GLW',
#   'Company': 'Corning Inc.',
#   'Sub_sector': 'Electronic Components',
#   'Headquarters': 'Corning, New York',
#   'Date added': '1995-02-27',
#   'Founded': '1851',
#   'LogoPath': 'NotAvailable'},
#  {'id': 133,
#   'Ticker': 'CTVA',
#   'Company': 'Corteva',
#   'Sub_sector': 'Fertilizers & Agricultural Chemicals',
#   'Headquarters': 'Indianapolis, Indiana',
#   'Date added': '2019-06-03',
#   'Founded': '2019',
#   'LogoPath': 'NotAvailable'},
#  {'id': 134,
#   'Ticker': 'CSGP',
#   'Company': 'CoStar Group',
#   'Sub_sector': 'Research & Consulting Services',
#   'Headquarters': 'Washington, D.C.',
#   'Date added': '2022-09-19',
#   'Founded': '1987',
#   'LogoPath': 'NotAvailable'},
#  {'id': 135,
#   'Ticker': 'COST',
#   'Company': 'Costco',
#   'Sub_sector': 'Consumer Staples Merchandise Retail',
#   'Headquarters': 'Issaquah, Washington',
#   'Date added': '1993-10-01',
#   'Founded': '1976',
#   'LogoPath': 'NotAvailable'},
#  {'id': 136,
#   'Ticker': 'CTRA',
#   'Company': 'Coterra',
#   'Sub_sector': 'Oil & Gas Exploration & Production',
#   'Headquarters': 'Houston, Texas',
#   'Date added': '2008-06-23',
#   'Founded': '2021 (1989)',
#   'LogoPath': 'NotAvailable'},
#  {'id': 137,
#   'Ticker': 'CCI',
#   'Company': 'Crown Castle',
#   'Sub_sector': 'Telecom Tower REITs',
#   'Headquarters': 'Houston, Texas',
#   'Date added': '2012-03-14',
#   'Founded': '1994',
#   'LogoPath': 'NotAvailable'},
#  {'id': 138,
#   'Ticker': 'CSX',
#   'Company': 'CSX',
#   'Sub_sector': 'Rail Transportation',
#   'Headquarters': 'Jacksonville, Florida',
#   'Date added': '1957-03-04',
#   'Founded': '1980',
#   'LogoPath': 'NotAvailable'},
#  {'id': 139,
#   'Ticker': 'CMI',
#   'Company': 'Cummins',
#   'Sub_sector': 'Industrial Machinery & Supplies & Components',
#   'Headquarters': 'Columbus, Indiana',
#   'Date added': '1965-03-31',
#   'Founded': '1919',
#   'LogoPath': 'NotAvailable'},
#  {'id': 140,
#   'Ticker': 'CVS',
#   'Company': 'CVS Health',
#   'Sub_sector': 'Health Care Services',
#   'Headquarters': 'Woonsocket, Rhode Island',
#   'Date added': '1957-03-04',
#   'Founded': '1996',
#   'LogoPath': 'NotAvailable'},
#  {'id': 141,
#   'Ticker': 'DHI',
#   'Company': 'D.R. Horton',
#   'Sub_sector': 'Homebuilding',
#   'Headquarters': 'Arlington, Texas',
#   'Date added': '2005-06-22',
#   'Founded': '1978',
#   'LogoPath': 'NotAvailable'},
#  {'id': 142,
#   'Ticker': 'DHR',
#   'Company': 'Danaher Corporation',
#   'Sub_sector': 'Health Care Equipment',
#   'Headquarters': 'Washington, D.C.',
#   'Date added': '1998-11-18',
#   'Founded': '1969',
#   'LogoPath': 'NotAvailable'},
#  {'id': 143,
#   'Ticker': 'DRI',
#   'Company': 'Darden Restaurants',
#   'Sub_sector': 'Restaurants',
#   'Headquarters': 'Orlando, Florida',
#   'Date added': '1995-05-31',
#   'Founded': '1938',
#   'LogoPath': 'NotAvailable'},
#  {'id': 144,
#   'Ticker': 'DVA',
#   'Company': 'DaVita Inc.',
#   'Sub_sector': 'Health Care Facilities',
#   'Headquarters': 'Denver, Colorado',
#   'Date added': '2008-07-31',
#   'Founded': '1979',
#   'LogoPath': 'NotAvailable'},
#  {'id': 145,
#   'Ticker': 'DE',
#   'Company': 'John Deere',
#   'Sub_sector': 'Agricultural & Farm Machinery',
#   'Headquarters': 'Moline, Illinois',
#   'Date added': '1957-03-04',
#   'Founded': '1837',
#   'LogoPath': 'NotAvailable'},
#  {'id': 146,
#   'Ticker': 'DAL',
#   'Company': 'Delta Air Lines',
#   'Sub_sector': 'Passenger Airlines',
#   'Headquarters': 'Atlanta, Georgia',
#   'Date added': '2013-09-11',
#   'Founded': '1929',
#   'LogoPath': 'NotAvailable'},
#  {'id': 147,
#   'Ticker': 'XRAY',
#   'Company': 'Dentsply Sirona',
#   'Sub_sector': 'Health Care Supplies',
#   'Headquarters': 'Charlotte, North Carolina',
#   'Date added': '2008-11-14',
#   'Founded': '2016 (1969)',
#   'LogoPath': 'NotAvailable'},
#  {'id': 148,
#   'Ticker': 'DVN',
#   'Company': 'Devon Energy',
#   'Sub_sector': 'Oil & Gas Exploration & Production',
#   'Headquarters': 'Oklahoma City, Oklahoma',
#   'Date added': '2000-08-30',
#   'Founded': '1971',
#   'LogoPath': 'NotAvailable'},
#  {'id': 149,
#   'Ticker': 'DXCM',
#   'Company': 'Dexcom',
#   'Sub_sector': 'Health Care Equipment',
#   'Headquarters': 'San Diego, California',
#   'Date added': '2020-05-12',
#   'Founded': '1999',
#   'LogoPath': 'NotAvailable'},
#  {'id': 150,
#   'Ticker': 'FANG',
#   'Company': 'Diamondback Energy',
#   'Sub_sector': 'Oil & Gas Exploration & Production',
#   'Headquarters': 'Midland, Texas',
#   'Date added': '2018-12-03',
#   'Founded': '2007',
#   'LogoPath': 'NotAvailable'},
#  {'id': 151,
#   'Ticker': 'DLR',
#   'Company': 'Digital Realty',
#   'Sub_sector': 'Data Center REITs',
#   'Headquarters': 'Austin, Texas',
#   'Date added': '2016-05-18',
#   'Founded': '2004',
#   'LogoPath': 'NotAvailable'},
#  {'id': 152,
#   'Ticker': 'DFS',
#   'Company': 'Discover Financial',
#   'Sub_sector': 'Consumer Finance',
#   'Headquarters': 'Riverwoods, Illinois',
#   'Date added': '2007-07-02',
#   'Founded': '1985',
#   'LogoPath': 'NotAvailable'},
#  {'id': 153,
#   'Ticker': 'DIS',
#   'Company': 'Disney',
#   'Sub_sector': 'Movies & Entertainment',
#   'Headquarters': 'Burbank, California',
#   'Date added': '1976-06-30',
#   'Founded': '1923',
#   'LogoPath': 'NotAvailable'},
#  {'id': 154,
#   'Ticker': 'DG',
#   'Company': 'Dollar General',
#   'Sub_sector': 'Consumer Staples Merchandise Retail',
#   'Headquarters': 'Goodlettsville, Tennessee',
#   'Date added': '2012-12-03',
#   'Founded': '1939',
#   'LogoPath': 'NotAvailable'},
#  {'id': 155,
#   'Ticker': 'DLTR',
#   'Company': 'Dollar Tree',
#   'Sub_sector': 'Consumer Staples Merchandise Retail',
#   'Headquarters': 'Chesapeake, Virginia',
#   'Date added': '2011-12-19',
#   'Founded': '1986',
#   'LogoPath': 'NotAvailable'},
#  {'id': 156,
#   'Ticker': 'D',
#   'Company': 'Dominion Energy',
#   'Sub_sector': 'Electric Utilities',
#   'Headquarters': 'Richmond, Virginia',
#   'Date added': '2011-12-20',
#   'Founded': '1983',
#   'LogoPath': 'NotAvailable'},
#  {'id': 157,
#   'Ticker': 'DPZ',
#   'Company': "Domino's",
#   'Sub_sector': 'Restaurants',
#   'Headquarters': 'Ann Arbor, Michigan',
#   'Date added': '2020-05-12',
#   'Founded': '1960',
#   'LogoPath': 'NotAvailable'},
#  {'id': 158,
#   'Ticker': 'DOV',
#   'Company': 'Dover Corporation',
#   'Sub_sector': 'Industrial Machinery & Supplies & Components',
#   'Headquarters': 'Downers Grove, Illinois',
#   'Date added': '1985-10-31',
#   'Founded': '1955',
#   'LogoPath': 'NotAvailable'},
#  {'id': 159,
#   'Ticker': 'DOW',
#   'Company': 'Dow Inc.',
#   'Sub_sector': 'Commodity Chemicals',
#   'Headquarters': 'Midland, Michigan',
#   'Date added': '2019-04-01',
#   'Founded': '2019',
#   'LogoPath': 'NotAvailable'},
#  {'id': 160,
#   'Ticker': 'DTE',
#   'Company': 'DTE Energy',
#   'Sub_sector': 'Multi-Utilities',
#   'Headquarters': 'Detroit, Michigan',
#   'Date added': '1957-03-04',
#   'Founded': '1995',
#   'LogoPath': 'NotAvailable'},
#  {'id': 161,
#   'Ticker': 'DUK',
#   'Company': 'Duke Energy',
#   'Sub_sector': 'Electric Utilities',
#   'Headquarters': 'Charlotte, North Carolina',
#   'Date added': '1976-06-30',
#   'Founded': '1904',
#   'LogoPath': 'NotAvailable'},
#  {'id': 162,
#   'Ticker': 'DD',
#   'Company': 'DuPont',
#   'Sub_sector': 'Specialty Chemicals',
#   'Headquarters': 'Wilmington, Delaware',
#   'Date added': '2019-04-02',
#   'Founded': '2017',
#   'LogoPath': 'NotAvailable'},
#  {'id': 163,
#   'Ticker': 'DXC',
#   'Company': 'DXC Technology',
#   'Sub_sector': 'IT Consulting & Other Services',
#   'Headquarters': 'Tysons Corner, Virginia',
#   'Date added': '2017-04-04',
#   'Founded': '2017',
#   'LogoPath': './Resources/DXC.png'},
#  {'id': 164,
#   'Ticker': 'EMN',
#   'Company': 'Eastman Chemical Company',
#   'Sub_sector': 'Diversified Chemicals',
#   'Headquarters': 'Kingsport, Tennessee',
#   'Date added': '1994-01-01',
#   'Founded': '1920',
#   'LogoPath': 'NotAvailable'},
#  {'id': 165,
#   'Ticker': 'ETN',
#   'Company': 'Eaton Corporation',
#   'Sub_sector': 'Electrical Components & Equipment',
#   'Headquarters': 'Dublin, Ireland',
#   'Date added': '1957-03-04',
#   'Founded': '1911',
#   'LogoPath': 'NotAvailable'},
#  {'id': 166,
#   'Ticker': 'EBAY',
#   'Company': 'eBay',
#   'Sub_sector': 'Broadline Retail',
#   'Headquarters': 'San Jose, California',
#   'Date added': '2002-07-22',
#   'Founded': '1995',
#   'LogoPath': 'NotAvailable'},
#  {'id': 167,
#   'Ticker': 'ECL',
#   'Company': 'Ecolab',
#   'Sub_sector': 'Specialty Chemicals',
#   'Headquarters': 'Saint Paul, Minnesota',
#   'Date added': '1989-01-31',
#   'Founded': '1923',
#   'LogoPath': 'NotAvailable'},
#  {'id': 168,
#   'Ticker': 'EIX',
#   'Company': 'Edison International',
#   'Sub_sector': 'Electric Utilities',
#   'Headquarters': 'Rosemead, California',
#   'Date added': '1957-03-04',
#   'Founded': '1886',
#   'LogoPath': 'NotAvailable'},
#  {'id': 169,
#   'Ticker': 'EW',
#   'Company': 'Edwards Lifesciences',
#   'Sub_sector': 'Health Care Equipment',
#   'Headquarters': 'Irvine, California',
#   'Date added': '2011-04-01',
#   'Founded': '1958',
#   'LogoPath': 'NotAvailable'},
#  {'id': 170,
#   'Ticker': 'EA',
#   'Company': 'Electronic Arts',
#   'Sub_sector': 'Interactive Home Entertainment',
#   'Headquarters': 'Redwood City, California',
#   'Date added': '2002-07-22',
#   'Founded': '1982',
#   'LogoPath': 'NotAvailable'},
#  {'id': 171,
#   'Ticker': 'ELV',
#   'Company': 'Elevance Health',
#   'Sub_sector': 'Managed Health Care',
#   'Headquarters': 'Indianapolis, Indiana',
#   'Date added': '2002-07-25',
#   'Founded': '2014 (1946)',
#   'LogoPath': 'NotAvailable'},
#  {'id': 172,
#   'Ticker': 'LLY',
#   'Company': 'Eli Lilly and Company',
#   'Sub_sector': 'Pharmaceuticals',
#   'Headquarters': 'Indianapolis, Indiana',
#   'Date added': '1970-12-31',
#   'Founded': '1876',
#   'LogoPath': 'NotAvailable'},
#  {'id': 173,
#   'Ticker': 'EMR',
#   'Company': 'Emerson Electric',
#   'Sub_sector': 'Electrical Components & Equipment',
#   'Headquarters': 'Ferguson, Missouri',
#   'Date added': '1965-03-31',
#   'Founded': '1890',
#   'LogoPath': 'NotAvailable'},
#  {'id': 174,
#   'Ticker': 'ENPH',
#   'Company': 'Enphase',
#   'Sub_sector': 'Electronic Components',
#   'Headquarters': 'Fremont, California',
#   'Date added': '2021-01-07',
#   'Founded': '2006',
#   'LogoPath': 'NotAvailable'},
#  {'id': 175,
#   'Ticker': 'ETR',
#   'Company': 'Entergy',
#   'Sub_sector': 'Electric Utilities',
#   'Headquarters': 'New Orleans, Louisiana',
#   'Date added': '1957-03-04',
#   'Founded': '1913',
#   'LogoPath': 'NotAvailable'},
#  {'id': 176,
#   'Ticker': 'EOG',
#   'Company': 'EOG Resources',
#   'Sub_sector': 'Oil & Gas Exploration & Production',
#   'Headquarters': 'Houston, Texas',
#   'Date added': '2000-11-02',
#   'Founded': '1999',
#   'LogoPath': 'NotAvailable'},
#  {'id': 177,
#   'Ticker': 'EPAM',
#   'Company': 'EPAM Systems',
#   'Sub_sector': 'IT Consulting & Other Services',
#   'Headquarters': 'Newtown, Pennsylvania',
#   'Date added': '2021-12-14',
#   'Founded': '1993',
#   'LogoPath': 'NotAvailable'},
#  {'id': 178,
#   'Ticker': 'EQT',
#   'Company': 'EQT',
#   'Sub_sector': 'Oil & Gas Exploration & Production',
#   'Headquarters': 'Pittsburgh, Pennsylvania',
#   'Date added': '2022-10-03',
#   'Founded': '1888',
#   'LogoPath': 'NotAvailable'},
#  {'id': 179,
#   'Ticker': 'EFX',
#   'Company': 'Equifax',
#   'Sub_sector': 'Research & Consulting Services',
#   'Headquarters': 'Atlanta, Georgia',
#   'Date added': '1997-06-19',
#   'Founded': '1899',
#   'LogoPath': 'NotAvailable'},
#  {'id': 180,
#   'Ticker': 'EQIX',
#   'Company': 'Equinix',
#   'Sub_sector': 'Data Center REITs',
#   'Headquarters': 'Redwood City, California',
#   'Date added': '2015-03-20',
#   'Founded': '1998',
#   'LogoPath': 'NotAvailable'},
#  {'id': 181,
#   'Ticker': 'EQR',
#   'Company': 'Equity Residential',
#   'Sub_sector': 'Residential REITs',
#   'Headquarters': 'Chicago, Illinois',
#   'Date added': '2001-12-03',
#   'Founded': '1969',
#   'LogoPath': 'NotAvailable'},
#  {'id': 182,
#   'Ticker': 'ESS',
#   'Company': 'Essex Property Trust',
#   'Sub_sector': 'Residential REITs',
#   'Headquarters': 'San Mateo, California',
#   'Date added': '2014-04-02',
#   'Founded': '1971',
#   'LogoPath': 'NotAvailable'},
#  {'id': 183,
#   'Ticker': 'EL',
#   'Company': 'Estée Lauder Companies (The)',
#   'Sub_sector': 'Personal Care Products',
#   'Headquarters': 'New York City, New York',
#   'Date added': '2006-01-05',
#   'Founded': '1946',
#   'LogoPath': 'NotAvailable'},
#  {'id': 184,
#   'Ticker': 'ETSY',
#   'Company': 'Etsy',
#   'Sub_sector': 'Broadline Retail',
#   'Headquarters': 'New York City, New York',
#   'Date added': '2020-09-21',
#   'Founded': '2005',
#   'LogoPath': 'NotAvailable'},
#  {'id': 185,
#   'Ticker': 'EG',
#   'Company': 'Everest Re',
#   'Sub_sector': 'Reinsurance',
#   'Headquarters': 'Hamilton, Bermuda',
#   'Date added': '2017-06-19',
#   'Founded': '1973',
#   'LogoPath': 'NotAvailable'},
#  {'id': 186,
#   'Ticker': 'EVRG',
#   'Company': 'Evergy',
#   'Sub_sector': 'Electric Utilities',
#   'Headquarters': 'Kansas City, Missouri',
#   'Date added': '2018-06-05',
#   'Founded': '1909',
#   'LogoPath': 'NotAvailable'},
#  {'id': 187,
#   'Ticker': 'ES',
#   'Company': 'Eversource',
#   'Sub_sector': 'Multi-Utilities',
#   'Headquarters': 'Hartford, Connecticut',
#   'Date added': '2009-01-01',
#   'Founded': '1966',
#   'LogoPath': 'NotAvailable'},
#  {'id': 188,
#   'Ticker': 'EXC',
#   'Company': 'Exelon',
#   'Sub_sector': 'Multi-Utilities',
#   'Headquarters': 'Chicago, Illinois',
#   'Date added': '1957-03-04',
#   'Founded': '2000',
#   'LogoPath': 'NotAvailable'},
#  {'id': 189,
#   'Ticker': 'EXPE',
#   'Company': 'Expedia Group',
#   'Sub_sector': 'Hotels, Restaurants & Leisure',
#   'Headquarters': 'Seattle, Washington',
#   'Date added': '2007-10-02',
#   'Founded': '1996',
#   'LogoPath': 'NotAvailable'},
#  {'id': 190,
#   'Ticker': 'EXPD',
#   'Company': 'Expeditors International',
#   'Sub_sector': 'Air Freight & Logistics',
#   'Headquarters': 'Seattle, Washington',
#   'Date added': '2007-10-10',
#   'Founded': '1979',
#   'LogoPath': 'NotAvailable'},
#  {'id': 191,
#   'Ticker': 'EXR',
#   'Company': 'Extra Space Storage',
#   'Sub_sector': 'Self-Storage REITs',
#   'Headquarters': 'Salt Lake City, Utah',
#   'Date added': '2016-01-19',
#   'Founded': '1977',
#   'LogoPath': 'NotAvailable'},
#  {'id': 192,
#   'Ticker': 'XOM',
#   'Company': 'ExxonMobil',
#   'Sub_sector': 'Integrated Oil & Gas',
#   'Headquarters': 'Irving, Texas',
#   'Date added': '1957-03-04',
#   'Founded': '1999',
#   'LogoPath': 'NotAvailable'},
#  {'id': 193,
#   'Ticker': 'FFIV',
#   'Company': 'F5, Inc.',
#   'Sub_sector': 'Communications Equipment',
#   'Headquarters': 'Seattle, Washington',
#   'Date added': '2010-12-20',
#   'Founded': '1996',
#   'LogoPath': './Resources/FFIV.png'},
#  {'id': 194,
#   'Ticker': 'FDS',
#   'Company': 'FactSet',
#   'Sub_sector': 'Financial Exchanges & Data',
#   'Headquarters': 'Norwalk, Connecticut',
#   'Date added': '2021-12-20',
#   'Founded': '1978',
#   'LogoPath': 'NotAvailable'},
#  {'id': 195,
#   'Ticker': 'FICO',
#   'Company': 'Fair Isaac',
#   'Sub_sector': 'Application Software',
#   'Headquarters': 'Bozeman, Montana',
#   'Date added': '2023-03-20',
#   'Founded': '1956',
#   'LogoPath': 'NotAvailable'},
#  {'id': 196,
#   'Ticker': 'FAST',
#   'Company': 'Fastenal',
#   'Sub_sector': 'Building Products',
#   'Headquarters': 'Winona, Minnesota',
#   'Date added': '2008-09-15',
#   'Founded': '1967',
#   'LogoPath': 'NotAvailable'},
#  {'id': 197,
#   'Ticker': 'FRT',
#   'Company': 'Federal Realty',
#   'Sub_sector': 'Retail REITs',
#   'Headquarters': 'Rockville, Maryland',
#   'Date added': '2016-02-01',
#   'Founded': '1962',
#   'LogoPath': 'NotAvailable'},
#  {'id': 198,
#   'Ticker': 'FDX',
#   'Company': 'FedEx',
#   'Sub_sector': 'Air Freight & Logistics',
#   'Headquarters': 'Memphis, Tennessee',
#   'Date added': '1980-12-31',
#   'Founded': '1971',
#   'LogoPath': 'NotAvailable'},
#  {'id': 199,
#   'Ticker': 'FITB',
#   'Company': 'Fifth Third Bank',
#   'Sub_sector': 'Regional Banks',
#   'Headquarters': 'Cincinnati, Ohio',
#   'Date added': '1996-03-29',
#   'Founded': '1858',
#   'LogoPath': 'NotAvailable'},
#  {'id': 200,
#   'Ticker': 'FSLR',
#   'Company': 'First Solar',
#   'Sub_sector': 'Semiconductors',
#   'Headquarters': 'Tempe, Arizona',
#   'Date added': '2022-12-19',
#   'Founded': '1999',
#   'LogoPath': 'NotAvailable'},
#  {'id': 201,
#   'Ticker': 'FE',
#   'Company': 'FirstEnergy',
#   'Sub_sector': 'Electric Utilities',
#   'Headquarters': 'Akron, Ohio',
#   'Date added': '1997-11-28',
#   'Founded': '1997',
#   'LogoPath': 'NotAvailable'},
#  {'id': 202,
#   'Ticker': 'FIS',
#   'Company': 'FIS',
#   'Sub_sector': 'Transaction & Payment Processing Services',
#   'Headquarters': 'Jacksonville, Florida',
#   'Date added': '2006-11-10',
#   'Founded': '1968',
#   'LogoPath': 'NotAvailable'},
#  {'id': 203,
#   'Ticker': 'FI',
#   'Company': 'Fiserv',
#   'Sub_sector': 'Transaction & Payment Processing Services',
#   'Headquarters': 'Brookfield, Wisconsin',
#   'Date added': '2001-04-02',
#   'Founded': '1984',
#   'LogoPath': 'NotAvailable'},
#  {'id': 204,
#   'Ticker': 'FLT',
#   'Company': 'Fleetcor',
#   'Sub_sector': 'Transaction & Payment Processing Services',
#   'Headquarters': 'Atlanta, Georgia',
#   'Date added': '2018-06-20',
#   'Founded': '2000',
#   'LogoPath': 'NotAvailable'},
#  {'id': 205,
#   'Ticker': 'FMC',
#   'Company': 'FMC Corporation',
#   'Sub_sector': 'Fertilizers & Agricultural Chemicals',
#   'Headquarters': 'Philadelphia, Pennsylvania',
#   'Date added': '2009-08-19',
#   'Founded': '1883',
#   'LogoPath': 'NotAvailable'},
#  {'id': 206,
#   'Ticker': 'F',
#   'Company': 'Ford Motor Company',
#   'Sub_sector': 'Automobile Manufacturers',
#   'Headquarters': 'Dearborn, Michigan',
#   'Date added': '1957-03-04',
#   'Founded': '1903',
#   'LogoPath': 'NotAvailable'},
#  {'id': 207,
#   'Ticker': 'FTNT',
#   'Company': 'Fortinet',
#   'Sub_sector': 'Systems Software',
#   'Headquarters': 'Sunnyvale, California',
#   'Date added': '2018-10-11',
#   'Founded': '2000',
#   'LogoPath': 'NotAvailable'},
#  {'id': 208,
#   'Ticker': 'FTV',
#   'Company': 'Fortive',
#   'Sub_sector': 'Industrial Machinery & Supplies & Components',
#   'Headquarters': 'Everett, Washington',
#   'Date added': '2016-07-01',
#   'Founded': '2016',
#   'LogoPath': 'NotAvailable'},
#  {'id': 209,
#   'Ticker': 'FOXA',
#   'Company': 'Fox Corporation (Class A)',
#   'Sub_sector': 'Movies & Entertainment',
#   'Headquarters': 'New York City, New York',
#   'Date added': '2013-07-01',
#   'Founded': '2019',
#   'LogoPath': 'NotAvailable'},
#  {'id': 210,
#   'Ticker': 'FOX',
#   'Company': 'Fox Corporation (Class B)',
#   'Sub_sector': 'Movies & Entertainment',
#   'Headquarters': 'New York City, New York',
# ...
#   'Headquarters': 'Houston, Texas',
#   'Date added': '1986-12-31',
#   'Founded': '1969',
#   'LogoPath': 'NotAvailable'},
#  {'id': 436,
#   'Ticker': 'TMUS',
#   'Company': 'T-Mobile US',
#   'Sub_sector': 'Wireless Telecommunication Services',
#   'Headquarters': 'Bellevue, Washington',
#   'Date added': '2019-07-15',
#   'Founded': '1994',
#   'LogoPath': 'NotAvailable'},
#  {'id': 437,
#   'Ticker': 'TROW',
#   'Company': 'T. Rowe Price',
#   'Sub_sector': 'Asset Management & Custody Banks',
#   'Headquarters': 'Baltimore, Maryland',
#   'Date added': '2019-07-16',
#   'Founded': '1937',
#   'LogoPath': 'NotAvailable'},
#  {'id': 438,
#   'Ticker': 'TTWO',
#   'Company': 'Take-Two Interactive',
#   'Sub_sector': 'Interactive Home Entertainment',
#   'Headquarters': 'New York City, New York',
#   'Date added': '2018-03-19',
#   'Founded': '1993',
#   'LogoPath': 'NotAvailable'},
#  {'id': 439,
#   'Ticker': 'TPR',
#   'Company': 'Tapestry, Inc.',
#   'Sub_sector': 'Apparel, Accessories & Luxury Goods',
#   'Headquarters': 'New York City, New York',
#   'Date added': '2004-09-01',
#   'Founded': '2017',
#   'LogoPath': 'NotAvailable'},
#  {'id': 440,
#   'Ticker': 'TRGP',
#   'Company': 'Targa Resources',
#   'Sub_sector': 'Oil & Gas Storage & Transportation',
#   'Headquarters': 'Houston, Texas',
#   'Date added': '2022-10-12',
#   'Founded': '2005',
#   'LogoPath': 'NotAvailable'},
#  {'id': 441,
#   'Ticker': 'TGT',
#   'Company': 'Target Corporation',
#   'Sub_sector': 'Consumer Staples Merchandise Retail',
#   'Headquarters': 'Minneapolis, Minnesota',
#   'Date added': '1976-12-31',
#   'Founded': '1902',
#   'LogoPath': 'NotAvailable'},
#  {'id': 442,
#   'Ticker': 'TEL',
#   'Company': 'TE Connectivity',
#   'Sub_sector': 'Electronic Manufacturing Services',
#   'Headquarters': 'Schaffhausen, Switzerland',
#   'Date added': '2011-10-17',
#   'Founded': '2007',
#   'LogoPath': 'NotAvailable'},
#  {'id': 443,
#   'Ticker': 'TDY',
#   'Company': 'Teledyne Technologies',
#   'Sub_sector': 'Electronic Equipment & Instruments',
#   'Headquarters': 'Thousand Oaks, California',
#   'Date added': '2020-06-22',
#   'Founded': '1960',
#   'LogoPath': 'NotAvailable'},
#  {'id': 444,
#   'Ticker': 'TFX',
#   'Company': 'Teleflex',
#   'Sub_sector': 'Health Care Equipment',
#   'Headquarters': 'Wayne, Pennsylvania',
#   'Date added': '2019-01-18',
#   'Founded': '1943',
#   'LogoPath': 'NotAvailable'},
#  {'id': 445,
#   'Ticker': 'TER',
#   'Company': 'Teradyne',
#   'Sub_sector': 'Semiconductor Materials & Equipment',
#   'Headquarters': 'North Reading, Massachusetts',
#   'Date added': '2020-09-21',
#   'Founded': '1960',
#   'LogoPath': 'NotAvailable'},
#  {'id': 446,
#   'Ticker': 'TSLA',
#   'Company': 'Tesla, Inc.',
#   'Sub_sector': 'Automobile Manufacturers',
#   'Headquarters': 'Austin, Texas',
#   'Date added': '2020-12-21',
#   'Founded': '2003',
#   'LogoPath': './Resources/TSLA.png'},
#  {'id': 447,
#   'Ticker': 'TXN',
#   'Company': 'Texas Instruments',
#   'Sub_sector': 'Semiconductors',
#   'Headquarters': 'Dallas, Texas',
#   'Date added': '2020-12-22',
#   'Founded': '1930',
#   'LogoPath': 'NotAvailable'},
#  {'id': 448,
#   'Ticker': 'TXT',
#   'Company': 'Textron',
#   'Sub_sector': 'Aerospace & Defense',
#   'Headquarters': 'Providence, Rhode Island',
#   'Date added': '1978-12-31',
#   'Founded': '1923',
#   'LogoPath': 'NotAvailable'},
#  {'id': 449,
#   'Ticker': 'TMO',
#   'Company': 'Thermo Fisher Scientific',
#   'Sub_sector': 'Life Sciences Tools & Services',
#   'Headquarters': 'Waltham, Massachusetts',
#   'Date added': '2004-08-03',
#   'Founded': '2006 (1902)',
#   'LogoPath': 'NotAvailable'},
#  {'id': 450,
#   'Ticker': 'TJX',
#   'Company': 'TJX Companies',
#   'Sub_sector': 'Apparel Retail',
#   'Headquarters': 'Framingham, Massachusetts',
#   'Date added': '1985-09-30',
#   'Founded': '1987',
#   'LogoPath': 'NotAvailable'},
#  {'id': 451,
#   'Ticker': 'TSCO',
#   'Company': 'Tractor Supply',
#   'Sub_sector': 'Specialty Stores',
#   'Headquarters': 'Brentwood, Tennessee',
#   'Date added': '2014-01-24',
#   'Founded': '1938',
#   'LogoPath': 'NotAvailable'},
#  {'id': 452,
#   'Ticker': 'TT',
#   'Company': 'Trane Technologies',
#   'Sub_sector': 'Building Products',
#   'Headquarters': 'Dublin, Ireland',
#   'Date added': '2010-11-17',
#   'Founded': '1871',
#   'LogoPath': 'NotAvailable'},
#  {'id': 453,
#   'Ticker': 'TDG',
#   'Company': 'TransDigm Group',
#   'Sub_sector': 'Aerospace & Defense',
#   'Headquarters': 'Cleveland, Ohio',
#   'Date added': '2016-06-03',
#   'Founded': '1993',
#   'LogoPath': 'NotAvailable'},
#  {'id': 454,
#   'Ticker': 'TRV',
#   'Company': 'Travelers Companies (The)',
#   'Sub_sector': 'Property & Casualty Insurance',
#   'Headquarters': 'New York City, New York',
#   'Date added': '2002-08-21',
#   'Founded': '1853',
#   'LogoPath': 'NotAvailable'},
#  {'id': 455,
#   'Ticker': 'TRMB',
#   'Company': 'Trimble Inc.',
#   'Sub_sector': 'Electronic Equipment & Instruments',
#   'Headquarters': 'Westminster, Colorado',
#   'Date added': '2021-01-21',
#   'Founded': '1978',
#   'LogoPath': 'NotAvailable'},
#  {'id': 456,
#   'Ticker': 'TFC',
#   'Company': 'Truist',
#   'Sub_sector': 'Regional Banks',
#   'Headquarters': 'Charlotte, North Carolina',
#   'Date added': '1997-12-04',
#   'Founded': '1872',
#   'LogoPath': 'NotAvailable'},
#  {'id': 457,
#   'Ticker': 'TYL',
#   'Company': 'Tyler Technologies',
#   'Sub_sector': 'Application Software',
#   'Headquarters': 'Plano, Texas',
#   'Date added': '2020-06-22',
#   'Founded': '1966',
#   'LogoPath': 'NotAvailable'},
#  {'id': 458,
#   'Ticker': 'TSN',
#   'Company': 'Tyson Foods',
#   'Sub_sector': 'Packaged Foods & Meats',
#   'Headquarters': 'Springdale, Arkansas',
#   'Date added': '2005-08-10',
#   'Founded': '1935',
#   'LogoPath': 'NotAvailable'},
#  {'id': 459,
#   'Ticker': 'USB',
#   'Company': 'U.S. Bank',
#   'Sub_sector': 'Diversified Banks',
#   'Headquarters': 'Minneapolis, Minnesota',
#   'Date added': '2005-08-11',
#   'Founded': '1968',
#   'LogoPath': 'NotAvailable'},
#  {'id': 460,
#   'Ticker': 'UDR',
#   'Company': 'UDR, Inc.',
#   'Sub_sector': 'Residential REITs',
#   'Headquarters': 'Highlands Ranch, Colorado',
#   'Date added': '2016-03-07',
#   'Founded': '1972',
#   'LogoPath': 'NotAvailable'},
#  {'id': 461,
#   'Ticker': 'ULTA',
#   'Company': 'Ulta Beauty',
#   'Sub_sector': 'Specialty Stores',
#   'Headquarters': 'Bolingbrook, Illinois',
#   'Date added': '2016-04-18',
#   'Founded': '1990',
#   'LogoPath': 'NotAvailable'},
#  {'id': 462,
#   'Ticker': 'UNP',
#   'Company': 'Union Pacific Corporation',
#   'Sub_sector': 'Rail Transportation',
#   'Headquarters': 'Omaha, Nebraska',
#   'Date added': '1957-03-04',
#   'Founded': '1862',
#   'LogoPath': 'NotAvailable'},
#  {'id': 463,
#   'Ticker': 'UAL',
#   'Company': 'United Airlines Holdings',
#   'Sub_sector': 'Passenger Airlines',
#   'Headquarters': 'Chicago, Illinois',
#   'Date added': '2015-09-03',
#   'Founded': '1967',
#   'LogoPath': 'NotAvailable'},
#  {'id': 464,
#   'Ticker': 'UPS',
#   'Company': 'United Parcel Service',
#   'Sub_sector': 'Air Freight & Logistics',
#   'Headquarters': 'Sandy Springs, Georgia',
#   'Date added': '2002-07-22',
#   'Founded': '1907',
#   'LogoPath': 'NotAvailable'},
#  {'id': 465,
#   'Ticker': 'URI',
#   'Company': 'United Rentals',
#   'Sub_sector': 'Trading Companies & Distributors',
#   'Headquarters': 'Stamford, Connecticut',
#   'Date added': '2014-09-20',
#   'Founded': '1997',
#   'LogoPath': 'NotAvailable'},
#  {'id': 466,
#   'Ticker': 'UNH',
#   'Company': 'UnitedHealth Group',
#   'Sub_sector': 'Managed Health Care',
#   'Headquarters': 'Minnetonka, Minnesota',
#   'Date added': '1994-07-01',
#   'Founded': '1977',
#   'LogoPath': 'NotAvailable'},
#  {'id': 467,
#   'Ticker': 'UHS',
#   'Company': 'Universal Health Services',
#   'Sub_sector': 'Health Care Facilities',
#   'Headquarters': 'King of Prussia, Pennsylvania',
#   'Date added': '2014-09-20',
#   'Founded': '1979',
#   'LogoPath': 'NotAvailable'},
#  {'id': 468,
#   'Ticker': 'VLO',
#   'Company': 'Valero Energy',
#   'Sub_sector': 'Oil & Gas Refining & Marketing',
#   'Headquarters': 'San Antonio, Texas',
#   'Date added': '2002-12-20',
#   'Founded': '1980',
#   'LogoPath': 'NotAvailable'},
#  {'id': 469,
#   'Ticker': 'VTR',
#   'Company': 'Ventas',
#   'Sub_sector': 'Health Care REITs',
#   'Headquarters': 'Chicago, Illinois',
#   'Date added': '2009-03-04',
#   'Founded': '1998',
#   'LogoPath': 'NotAvailable'},
#  {'id': 470,
#   'Ticker': 'VRSN',
#   'Company': 'Verisign',
#   'Sub_sector': 'Internet Services & Infrastructure',
#   'Headquarters': 'Dulles, Virginia',
#   'Date added': '2006-02-01',
#   'Founded': '1995',
#   'LogoPath': 'NotAvailable'},
#  {'id': 471,
#   'Ticker': 'VRSK',
#   'Company': 'Verisk',
#   'Sub_sector': 'Research & Consulting Services',
#   'Headquarters': 'Jersey City, New Jersey',
#   'Date added': '2015-10-08',
#   'Founded': '1971',
#   'LogoPath': 'NotAvailable'},
#  {'id': 472,
#   'Ticker': 'VZ',
#   'Company': 'Verizon',
#   'Sub_sector': 'Integrated Telecommunication Services',
#   'Headquarters': 'New York City, New York',
#   'Date added': '1983-11-30',
#   'Founded': '1983 (1877)',
#   'LogoPath': 'NotAvailable'},
#  {'id': 473,
#   'Ticker': 'VRTX',
#   'Company': 'Vertex Pharmaceuticals',
#   'Sub_sector': 'Biotechnology',
#   'Headquarters': 'Cambridge, Massachusetts',
#   'Date added': '2013-09-23',
#   'Founded': '1989',
#   'LogoPath': 'NotAvailable'},
#  {'id': 474,
#   'Ticker': 'VFC',
#   'Company': 'VF Corporation',
#   'Sub_sector': 'Apparel, Accessories & Luxury Goods',
#   'Headquarters': 'Denver, Colorado',
#   'Date added': '1979-06-30',
#   'Founded': '1899',
#   'LogoPath': 'NotAvailable'},
#  {'id': 475,
#   'Ticker': 'VTRS',
#   'Company': 'Viatris',
#   'Sub_sector': 'Pharmaceuticals',
#   'Headquarters': 'Pittsburgh, Pennsylvania',
#   'Date added': '2004-04-23',
#   'Founded': '1961',
#   'LogoPath': 'NotAvailable'},
#  {'id': 476,
#   'Ticker': 'VICI',
#   'Company': 'Vici Properties',
#   'Sub_sector': 'Hotel & Resort REITs',
#   'Headquarters': 'New York City, New York',
#   'Date added': '2022-06-08',
#   'Founded': '2017',
#   'LogoPath': 'NotAvailable'},
#  {'id': 477,
#   'Ticker': 'V',
#   'Company': 'Visa Inc.',
#   'Sub_sector': 'Transaction & Payment Processing Services',
#   'Headquarters': 'San Francisco, California',
#   'Date added': '2009-12-21',
#   'Founded': '1958',
#   'LogoPath': 'NotAvailable'},
#  {'id': 478,
#   'Ticker': 'VMC',
#   'Company': 'Vulcan Materials Company',
#   'Sub_sector': 'Construction Materials',
#   'Headquarters': 'Birmingham, Alabama',
#   'Date added': '1999-06-30',
#   'Founded': '1909',
#   'LogoPath': 'NotAvailable'},
#  {'id': 479,
#   'Ticker': 'WAB',
#   'Company': 'Wabtec',
#   'Sub_sector': 'Construction Machinery & Heavy Transportation Equipment',
#   'Headquarters': 'Pittsburgh, Pennsylvania',
#   'Date added': '2019-02-27',
#   'Founded': '1999 (1869)',
#   'LogoPath': 'NotAvailable'},
#  {'id': 480,
#   'Ticker': 'WBA',
#   'Company': 'Walgreens Boots Alliance',
#   'Sub_sector': 'Drug Retail',
#   'Headquarters': 'Deerfield, Illinois',
#   'Date added': '1979-12-31',
#   'Founded': '2014',
#   'LogoPath': 'NotAvailable'},
#  {'id': 481,
#   'Ticker': 'WMT',
#   'Company': 'Walmart',
#   'Sub_sector': 'Consumer Staples Merchandise Retail',
#   'Headquarters': 'Bentonville, Arkansas',
#   'Date added': '1982-08-31',
#   'Founded': '1962',
#   'LogoPath': 'NotAvailable'},
#  {'id': 482,
#   'Ticker': 'WBD',
#   'Company': 'Warner Bros. Discovery',
#   'Sub_sector': 'Broadcasting',
#   'Headquarters': 'New York City, New York',
#   'Date added': '2022-04-11',
#   'Founded': '2022',
#   'LogoPath': 'NotAvailable'},
#  {'id': 483,
#   'Ticker': 'WM',
#   'Company': 'Waste Management',
#   'Sub_sector': 'Environmental & Facilities Services',
#   'Headquarters': 'Houston, Texas',
#   'Date added': '2022-04-12',
#   'Founded': '1968',
#   'LogoPath': 'NotAvailable'},
#  {'id': 484,
#   'Ticker': 'WAT',
#   'Company': 'Waters Corporation',
#   'Sub_sector': 'Health Care Distributors',
#   'Headquarters': 'Milford, Massachusetts',
#   'Date added': '2002-01-02',
#   'Founded': '1958',
#   'LogoPath': 'NotAvailable'},
#  {'id': 485,
#   'Ticker': 'WEC',
#   'Company': 'WEC Energy Group',
#   'Sub_sector': 'Electric Utilities',
#   'Headquarters': 'Milwaukee, Wisconsin',
#   'Date added': '2008-10-31',
#   'Founded': '1896',
#   'LogoPath': 'NotAvailable'},
#  {'id': 486,
#   'Ticker': 'WFC',
#   'Company': 'Wells Fargo',
#   'Sub_sector': 'Diversified Banks',
#   'Headquarters': 'San Francisco, California',
#   'Date added': '1976-06-30',
#   'Founded': '1852',
#   'LogoPath': 'NotAvailable'},
#  {'id': 487,
#   'Ticker': 'WELL',
#   'Company': 'Welltower',
#   'Sub_sector': 'Health Care REITs',
#   'Headquarters': 'Toledo, Ohio',
#   'Date added': '2009-01-30',
#   'Founded': '1970',
#   'LogoPath': 'NotAvailable'},
#  {'id': 488,
#   'Ticker': 'WST',
#   'Company': 'West Pharmaceutical Services',
#   'Sub_sector': 'Health Care Supplies',
#   'Headquarters': 'Exton, Pennsylvania',
#   'Date added': '2020-05-22',
#   'Founded': '1923',
#   'LogoPath': 'NotAvailable'},
#  {'id': 489,
#   'Ticker': 'WDC',
#   'Company': 'Western Digital',
#   'Sub_sector': 'Technology Hardware, Storage & Peripherals',
#   'Headquarters': 'San Jose, California',
#   'Date added': '2009-07-01',
#   'Founded': '1970',
#   'LogoPath': 'NotAvailable'},
#  {'id': 490,
#   'Ticker': 'WRK',
#   'Company': 'WestRock',
#   'Sub_sector': 'Paper & Plastic Packaging Products & Materials',
#   'Headquarters': 'Atlanta, Georgia',
#   'Date added': '1957-03-04',
#   'Founded': '2015',
#   'LogoPath': 'NotAvailable'},
#  {'id': 491,
#   'Ticker': 'WY',
#   'Company': 'Weyerhaeuser',
#   'Sub_sector': 'Timber REITs',
#   'Headquarters': 'Seattle, Washington',
#   'Date added': '1957-03-05',
#   'Founded': '1900',
#   'LogoPath': 'NotAvailable'},
#  {'id': 492,
#   'Ticker': 'WHR',
#   'Company': 'Whirlpool Corporation',
#   'Sub_sector': 'Household Appliances',
#   'Headquarters': 'Benton Harbor, Michigan',
#   'Date added': '1975-03-30',
#   'Founded': '1911',
#   'LogoPath': 'NotAvailable'},
#  {'id': 493,
#   'Ticker': 'WMB',
#   'Company': 'Williams Companies',
#   'Sub_sector': 'Oil & Gas Storage & Transportation',
#   'Headquarters': 'Tulsa, Oklahoma',
#   'Date added': '1975-03-31',
#   'Founded': '1908',
#   'LogoPath': 'NotAvailable'},
#  {'id': 494,
#   'Ticker': 'WTW',
#   'Company': 'Willis Towers Watson',
#   'Sub_sector': 'Insurance Brokers',
#   'Headquarters': 'London, United Kingdom',
#   'Date added': '2016-01-05',
#   'Founded': '2016',
#   'LogoPath': 'NotAvailable'},
#  {'id': 495,
#   'Ticker': 'GWW',
#   'Company': 'W. W. Grainger',
#   'Sub_sector': 'Industrial Machinery & Supplies & Components',
#   'Headquarters': 'Lake Forest, Illinois',
#   'Date added': '1981-06-30',
#   'Founded': '1927',
#   'LogoPath': 'NotAvailable'},
#  {'id': 496,
#   'Ticker': 'WYNN',
#   'Company': 'Wynn Resorts',
#   'Sub_sector': 'Casinos & Gaming',
#   'Headquarters': 'Paradise, Nevada',
#   'Date added': '2008-11-14',
#   'Founded': '2002',
#   'LogoPath': 'NotAvailable'},
#  {'id': 497,
#   'Ticker': 'XEL',
#   'Company': 'Xcel Energy',
#   'Sub_sector': 'Multi-Utilities',
#   'Headquarters': 'Minneapolis, Minnesota',
#   'Date added': '1957-03-04',
#   'Founded': '1909',
#   'LogoPath': 'NotAvailable'},
#  {'id': 498,
#   'Ticker': 'XYL',
#   'Company': 'Xylem Inc.',
#   'Sub_sector': 'Industrial Machinery & Supplies & Components',
#   'Headquarters': 'White Plains, New York',
#   'Date added': '2011-11-01',
#   'Founded': '2011',
#   'LogoPath': 'NotAvailable'},
#  {'id': 499,
#   'Ticker': 'YUM',
#   'Company': 'Yum! Brands',
#   'Sub_sector': 'Restaurants',
#   'Headquarters': 'Louisville, Kentucky',
#   'Date added': '1997-10-06',
#   'Founded': '1997',
#   'LogoPath': 'NotAvailable'},
#  {'id': 500,
#   'Ticker': 'ZBRA',
#   'Company': 'Zebra Technologies',
#   'Sub_sector': 'Electronic Equipment & Instruments',
#   'Headquarters': 'Lincolnshire, Illinois',
#   'Date added': '2019-12-23',
#   'Founded': '1969',
#   'LogoPath': 'NotAvailable'},
#  {'id': 501,
#   'Ticker': 'ZBH',
#   'Company': 'Zimmer Biomet',
#   'Sub_sector': 'Health Care Equipment',
#   'Headquarters': 'Warsaw, Indiana',
#   'Date added': '2001-08-07',
#   'Founded': '1927',
#   'LogoPath': './Resources/ZBH.png'},
#  {'id': 502,
#   'Ticker': 'ZION',
#   'Company': 'Zions Bancorporation',
#   'Sub_sector': 'Regional Banks',
#   'Headquarters': 'Salt Lake City, Utah',
#   'Date added': '2001-06-22',
#   'Founded': '1873',
#   'LogoPath': 'NotAvailable'},
#  {'id': 503,
#   'Ticker': 'ZTS',
#   'Company': 'Zoetis',
#   'Sub_sector': 'Pharmaceuticals',
#   'Headquarters': 'Parsippany, New Jersey',
#   'Date added': '2013-06-21',
#   'Founded': '1952',
#   'LogoPath': 'NotAvailable'}]

# %%
# metadata2 = jsonify(df)
# metadata2

# %%
df = pd.read_sql_query("SELECT * FROM AAPL", conn)
df
# Out:
#     id        Date        Open        High         Low       Close  \
# 0    1  2018-01-01   42.540001   45.025002   41.174999   41.857498
# 1    2  2018-02-01   41.792500   45.154999   37.560001   44.529999
# 2    3  2018-03-01   44.634998   45.875000   41.235001   41.945000
# 3    4  2018-04-01   41.660000   44.735001   40.157501   41.314999
# 4    5  2018-05-01   41.602501   47.592499   41.317501   46.717499
# ..  ..         ...         ...         ...         ...         ...
# 62  63  2023-03-01  146.830002  165.000000  143.899994  164.899994
# 63  64  2023-04-01  164.270004  169.850006  159.779999  169.679993
# 64  65  2023-05-01  169.279999  179.350006  164.309998  177.250000
# 65  66  2023-06-01  177.699997  194.479996  176.929993  193.970001
# 66  67  2023-07-01  193.779999  198.229996  186.600006  196.449997
#
#      Adj Close      Volume
# 0    39.633190  2638717600
# 1    42.163677  3711577200
# 2    39.877968  2854910800
# 3    39.279011  2664617200
# 4    44.415291  2483905200
# ..         ...         ...
# 62  164.450150  1520266600
# 63  169.217117   969709700
# 64  176.766464  1275155500
# 65  193.708420  1297101100
# 66  196.185074   996066400
#
# [67 rows x 8 columns]

# %%
#5 Acquire the Records
set0 = pd.read_sql_query("SELECT * FROM AAPL", conn) #pd.read_csv('./Resources/ellis_data/AAPL.csv')
set1 = pd.read_sql_query("SELECT * FROM AMZN", conn) #pd.read_csv('./Resources/ellis_data/AMZN.csv')
set2 = pd.read_sql_query("SELECT * FROM GOOGL", conn) #pd.read_csv('./Resources/ellis_data/GOOGL.csv')
set3 = pd.read_sql_query("SELECT * FROM META", conn) #pd.read_csv('./Resources/ellis_data/META.csv')
set4 = pd.read_sql_query("SELECT * FROM MSFT", conn) #pd.read_csv('./Resources/ellis_data/MSFT.csv')
set5 = pd.read_sql_query("SELECT * FROM NDVA", conn) #pd.read_csv('./Resources/ellis_data/NDVA.csv')
set6 = pd.read_sql_query("SELECT * FROM TSLA", conn) #pd.read_csv('./Resources/ellis_data/TSLA.csv')
#------------
set7 = pd.read_sql_query("SELECT * FROM DXC", conn) #pd.read_csv('./Resources/uwagboe_data/DXC.csv')
set8 = pd.read_sql_query("SELECT * FROM FFIV", conn) #pd.read_csv('./Resources/uwagboe_data/FFIV.csv')
set9 = pd.read_sql_query("SELECT * FROM JNPR", conn) #pd.read_csv('./Resources/uwagboe_data/JNPR.csv')
set10 = pd.read_sql_query("SELECT * FROM QRVO", conn) #pd.read_csv('./Resources/uwagboe_data/QRVO.csv')
set11 = pd.read_sql_query("SELECT * FROM SEDG", conn) #pd.read_csv('./Resources/uwagboe_data/SEDG.csv')
#------------
set12 = pd.read_sql_query("SELECT * FROM ANSS", conn) #pd.read_csv('./Resources/arefin_data/ANSS-Ansys_monthly_5yrs.csv')
set13 = pd.read_sql_query("SELECT * FROM GE", conn) #pd.read_csv('./Resources/arefin_data/GE-General Electric_monthly_5yrs.csv')
set14 = pd.read_sql_query("SELECT * FROM HPE", conn) #pd.read_csv('./Resources/arefin_data/HPE-Hawlett Packard_monthly_5yrs.csv')
set15 = pd.read_sql_query("SELECT * FROM KEYS", conn) #pd.read_csv('./Resources/arefin_data/KEYS-Keysight Holdings_monthly_5yrs.csv')
set16 = pd.read_sql_query("SELECT * FROM MTD", conn) #pd.read_csv('./Resources/arefin_data/MTD-Mettler Toledo_monthly_5yrs.csv')
set17 = pd.read_sql_query("SELECT * FROM ZBH", conn) #pd.read_csv('./Resources/arefin_data/ZBH-Zimmer Biomet Holdings_monthly_5yrs.csv')

df_sets = ["set" + str(i) for i in range(18)]

tickers = ["AAPL","AMZN","GOOGL","META","MSFT","NVDA","TSLA","DXC","FFIV","JNPR","QRVO","SEDG","ANSS","GE","HPE","KEYS","MTD","ZBH"] # df["Ticker"].tolist()

# %%
df_sets
# Out:
# ['set0',
#  'set1',
#  'set2',
#  'set3',
#  'set4',
#  'set5',
#  'set6',
#  'set7',
#  'set8',
#  'set9',
#  'set10',
#  'set11',
#  'set12',
#  'set13',
#  'set14',
#  'set15',
#  'set16',
#  'set17']

# %%
(globals()[df_sets[0]])["Date"]
# Out:
# 0     2018-01-01
# 1     2018-02-01
# 2     2018-03-01
# 3     2018-04-01
# 4     2018-05-01
#          ...
# 62    2023-03-01
# 63    2023-04-01
# 64    2023-05-01
# 65    2023-06-01
# 66    2023-07-01
# Name: Date, Length: 67, dtype: object

# %%
globals()[df_sets[0]]

# %%
stock_records = []
for cdf, ts in zip(df_sets, tickers):
    company_record={
        "ticker":ts,
        "dates":(globals()[cdf])["Date"].tolist(),
        "open": (globals()[cdf])["Open"].tolist(),
        "high": (globals()[cdf])["High"].tolist(),
        "low": (globals()[cdf])["Low"].tolist(),
        "close": (globals()[cdf])["Close"].tolist(),
        "adj close": (globals()[cdf])["Adj Close"].tolist(),
        "volume": (globals()[cdf])["Volume"].tolist()
    }
    stock_records.append(company_record)

final_dataset = {"tickers":tickers,
                 "company_info":metadata,
                 "stock_history": stock_records,
                }

print(final_dataset)

# %%
import json

final_dataset = {
    "tickers": tickers,
    "company_info": metadata,
    "stock_history": stock_records
}

# Save the final_dataset as a JSON file
with open('final_dataset.json', 'w') as json_file:
    json.dump(final_dataset, json_file, indent=4)
